# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports, top level definitions and data loading

# %%
import keras_lmu
import pandas as pd
import os
import tensorflow as tf

from core.pre_processing import build_ohio_dataset, build_windows, get_patient_window
from core.utils import compile_and_fit, plot_loss

# %%
# Path where to store the trained models
root_path = "models"

# %%
SAMPL_FREQ = 5

PATIENTS_2018 = ["559", "563", "570", "575", "588", "591"]
PATIENTS_2020 = ["540", "544", "552", "567", "584", "596"]

model_name = "lmu_2018_ph30min"

# %%
# Load dataset
dataset_2018 = build_ohio_dataset("2018")
# Out:
# Using time to peak: 100 for patient 559
# Identified 35 gaps for train set of 559
# Identified 7 gaps for val set of 559
# Identified 11 gaps for test set of 559
# Using time to peak: 100 for patient 563
# Identified 15 gaps for train set of 563
# Identified 6 gaps for val set of 563
# Identified 3 gaps for test set of 563
# Using time to peak: 100 for patient 570
# Identified 15 gaps for train set of 570
# Identified 5 gaps for val set of 570
# Identified 9 gaps for test set of 570
# Using time to peak: 100 for patient 575
# Identified 56 gaps for train set of 575
# Identified 16 gaps for val set of 575
# Identified 10 gaps for test set of 575
# Using time to peak: 100 for patient 588
# Identified 9 gaps for train set of 588
# Identified 1 gaps for val set of 588
# Identified 2 gaps for test set of 588
# Using time to peak: 100 for patient 591
# Identified 23 gaps for train set of 591
# Identified 3 gaps for val set of 591
# Identified 4 gaps for test set of 591

# %% [markdown]
# ## Setup params for the model and input

# %%
# 6 steps -> 30 minutes prediction horizon
PH = 6
batch_size = 256

# 30 minutes of input
input_len = 30

features = ["Time", "Glucose", "Rapid Insulin sub_tissue", "Carbohydrates gut", "finger_stick"]

# %% [markdown]
# ## Create pre-processed input-target pairs for the model
# Additionally create input-target pairs per each patient so that we can evaluate the performance individually per patient

# %%
w_2018, _ = build_windows(dataset_2018, features, input_len // SAMPL_FREQ, 1, PH, drop_noisy=False, batch_size=batch_size, min_max_scale=False)

# %%
patient_windows_2018 = {}
for p_tr_df, p_v_df, p_tst_df, patient_id in dataset_2018:
    patient_windows_2018[patient_id] = get_patient_window(
        (p_tr_df, p_v_df, p_tst_df),
        features,
        input_len // SAMPL_FREQ,
        1,
        PH,
        drop_noisy=False,
        batch_size=batch_size,
        min_max_scale=False
    )

# %% [markdown]
# ## Train and evaluate models

# %%
def train_model(patient_windows, model_name: str):
    lmu_layer = keras_lmu.LMU(
        memory_d=4,
        order=52,
        theta=input_len // SAMPL_FREQ,
        hidden_to_memory=True,
        memory_to_memory=False,
        input_to_hidden=False,
        hidden_cell=tf.keras.layers.LSTMCell(units=72),
        return_sequences=False,
        dropout=0.1,
        recurrent_dropout=0,
    )

    inputs = tf.keras.Input((input_len // SAMPL_FREQ, 4))
    lmus = lmu_layer(inputs)
    outputs = tf.keras.layers.Dense(1)(lmus)
    output_plus_input = tf.keras.layers.Add()([outputs, inputs[:, -1, 0]])

    model = tf.keras.Model(inputs=inputs, outputs=output_plus_input)
    print(model.summary())

    history = compile_and_fit(model, w_2018, max_epochs=300, learning_rate=10**-3, patience=35, store_model=model_name)
    plot_loss(history, "Loss", False)

    best_model = tf.keras.models.load_model(os.path.join(root_path, model_name))

    results_val = []
    results_test = []

    for patient_id, patient_w in patient_windows.items():
        print("Evaluating on patient_id:", patient_id)
        val_p = best_model.evaluate(patient_w.val, verbose=0)[1]
        test_p = best_model.evaluate(patient_w.test, verbose=0)[1]
        results_val.append((model_name, patient_id, val_p))
        results_test.append((model_name, patient_id, test_p))
    return results_val, results_test

# %%
val_errs, test_errs = train_model(patient_windows_2018, model_name)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 6, 4)]               0         []
#
#  lmu (LMU)                   (None, 72)                   81232     ['input_1[0][0]']
#
#  dense (Dense)               (None, 1)                    73        ['lmu[0][0]']
#
#  tf.__operators__.getitem (  (None,)                      0         ['input_1[0][0]']
#  SlicingOpLambda)
#
#  add (Add)                   (None, 1)                    0         ['dense[0][0]',
#                                                                      'tf.__operators__.getitem[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 81305 (317.60 KB)
# Trainable params: 81305 (317.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# all rolling: 9676
# 8748 size before reduction
# 8748 size after reduction
# 129 windows with too many nans
# 788 windows with empty labels
# all rolling: 10505
# 9862 size before reduction
# 9862 size after reduction
# 116 windows with too many nans
# 516 windows with empty labels
# all rolling: 9446
# 8866 size before reduction
# 8866 size after reduction
# 74 windows with too many nans
# 495 windows with empty labels
# all rolling: 10483
# 9765 size before reduction
# 9765 size after reduction
# 60 windows with too many nans
# 647 windows with empty labels
# all rolling: 10598
# 10117 size before reduction
# 10117 size after reduction
# 94 windows with too many nans
# 376 windows with empty labels
# all rolling: 10368
# 8588 size before reduction
# 8588 size after reduction
# 250 windows with too many nans
# 1519 windows with empty labels
# all rolling: 2420
# 2267 size before reduction
# 2267 size after reduction
# 22 windows with too many nans
# 120 windows with empty labels
# all rolling: 2627
# 2481 size before reduction
# 2481 size after reduction
# 33 windows with too many nans
# 102 windows with empty labels
# all rolling: 2362
# 2193 size before reduction
# 2193 size after reduction
# 25 windows with too many nans
# 133 windows with empty labels
# all rolling: 2621
# 2432 size before reduction
# 2432 size after reduction
# 23 windows with too many nans
# 155 windows with empty labels
# all rolling: 2650
# 2619 size before reduction
# 2619 size after reduction
# 5 windows with too many nans
# 15 windows with empty labels
# all rolling: 2592
# 2518 size before reduction
# 2518 size after reduction
# 12 windows with too many nans
# 51 windows with empty labels
# Epoch 1/300
# 219/219 [==============================] - 12s 34ms/step - loss: 562.2697 - root_mean_squared_error: 23.7122 - val_loss: 569.4495 - val_root_mean_squared_error: 23.8631 - lr: 0.0010
# Epoch 2/300
# 219/219 [==============================] - 7s 32ms/step - loss: 513.6760 - root_mean_squared_error: 22.6644 - val_loss: 536.3306 - val_root_mean_squared_error: 23.1588 - lr: 0.0010
# Epoch 3/300
# 219/219 [==============================] - 6s 28ms/step - loss: 493.0025 - root_mean_squared_error: 22.2037 - val_loss: 520.1619 - val_root_mean_squared_error: 22.8071 - lr: 0.0010
# Epoch 4/300
# 219/219 [==============================] - 7s 30ms/step - loss: 479.4446 - root_mean_squared_error: 21.8962 - val_loss: 505.8633 - val_root_mean_squared_error: 22.4914 - lr: 0.0010
# Epoch 5/300
# 219/219 [==============================] - 7s 34ms/step - loss: 470.9406 - root_mean_squared_error: 21.7012 - val_loss: 500.6168 - val_root_mean_squared_error: 22.3745 - lr: 0.0010
# Epoch 6/300
# 219/219 [==============================] - 6s 26ms/step - loss: 464.5252 - root_mean_squared_error: 21.5528 - val_loss: 494.4990 - val_root_mean_squared_error: 22.2373 - lr: 0.0010
# Epoch 7/300
# 219/219 [==============================] - 7s 34ms/step - loss: 458.4604 - root_mean_squared_error: 21.4117 - val_loss: 493.7979 - val_root_mean_squared_error: 22.2216 - lr: 0.0010
# Epoch 8/300
# 219/219 [==============================] - 7s 30ms/step - loss: 455.3496 - root_mean_squared_error: 21.3389 - val_loss: 490.8665 - val_root_mean_squared_error: 22.1555 - lr: 0.0010
# Epoch 9/300
# 219/219 [==============================] - 4s 17ms/step - loss: 451.7674 - root_mean_squared_error: 21.2548 - val_loss: 492.0870 - val_root_mean_squared_error: 22.1830 - lr: 0.0010
# Epoch 10/300
# 219/219 [==============================] - 8s 36ms/step - loss: 449.3593 - root_mean_squared_error: 21.1981 - val_loss: 485.2559 - val_root_mean_squared_error: 22.0285 - lr: 0.0010
# Epoch 11/300
# 219/219 [==============================] - 4s 17ms/step - loss: 445.6963 - root_mean_squared_error: 21.1115 - val_loss: 488.7805 - val_root_mean_squared_error: 22.1084 - lr: 0.0010
# Epoch 12/300
# 219/219 [==============================] - 5s 25ms/step - loss: 443.4016 - root_mean_squared_error: 21.0571 - val_loss: 486.1808 - val_root_mean_squared_error: 22.0495 - lr: 0.0010
# Epoch 13/300
# 219/219 [==============================] - 6s 29ms/step - loss: 441.8282 - root_mean_squared_error: 21.0197 - val_loss: 483.2452 - val_root_mean_squared_error: 21.9828 - lr: 0.0010
# Epoch 14/300
# 219/219 [==============================] - 6s 27ms/step - loss: 439.9276 - root_mean_squared_error: 20.9745 - val_loss: 482.4093 - val_root_mean_squared_error: 21.9638 - lr: 0.0010
# Epoch 15/300
# 219/219 [==============================] - 8s 34ms/step - loss: 435.5791 - root_mean_squared_error: 20.8705 - val_loss: 479.0075 - val_root_mean_squared_error: 21.8862 - lr: 0.0010
# Epoch 16/300
# 219/219 [==============================] - 7s 32ms/step - loss: 435.0507 - root_mean_squared_error: 20.8579 - val_loss: 476.8925 - val_root_mean_squared_error: 21.8379 - lr: 0.0010
# Epoch 17/300
# 219/219 [==============================] - 4s 17ms/step - loss: 434.5843 - root_mean_squared_error: 20.8467 - val_loss: 479.6626 - val_root_mean_squared_error: 21.9012 - lr: 0.0010
# Epoch 18/300
# 219/219 [==============================] - 6s 28ms/step - loss: 432.6278 - root_mean_squared_error: 20.7997 - val_loss: 474.8567 - val_root_mean_squared_error: 21.7912 - lr: 0.0010
# Epoch 19/300
# 219/219 [==============================] - 5s 21ms/step - loss: 430.3213 - root_mean_squared_error: 20.7442 - val_loss: 476.9906 - val_root_mean_squared_error: 21.8401 - lr: 0.0010
# Epoch 20/300
# 219/219 [==============================] - 4s 17ms/step - loss: 428.5231 - root_mean_squared_error: 20.7008 - val_loss: 475.1517 - val_root_mean_squared_error: 21.7980 - lr: 0.0010
# Epoch 21/300
# 219/219 [==============================] - 6s 25ms/step - loss: 428.8274 - root_mean_squared_error: 20.7081 - val_loss: 477.8405 - val_root_mean_squared_error: 21.8596 - lr: 0.0010
# Epoch 22/300
# 219/219 [==============================] - 4s 17ms/step - loss: 427.6548 - root_mean_squared_error: 20.6798 - val_loss: 475.7621 - val_root_mean_squared_error: 21.8120 - lr: 0.0010
# Epoch 23/300
# 219/219 [==============================] - 5s 24ms/step - loss: 427.0979 - root_mean_squared_error: 20.6663 - val_loss: 479.7814 - val_root_mean_squared_error: 21.9039 - lr: 0.0010
# Epoch 24/300
# 219/219 [==============================] - 4s 17ms/step - loss: 424.9391 - root_mean_squared_error: 20.6140 - val_loss: 475.2888 - val_root_mean_squared_error: 21.8011 - lr: 0.0010
# Epoch 25/300
# 219/219 [==============================] - 4s 17ms/step - loss: 426.4283 - root_mean_squared_error: 20.6501 - val_loss: 475.4096 - val_root_mean_squared_error: 21.8039 - lr: 0.0010
# Epoch 26/300
# 219/219 [==============================] - 7s 34ms/step - loss: 424.9951 - root_mean_squared_error: 20.6154 - val_loss: 473.3869 - val_root_mean_squared_error: 21.7575 - lr: 0.0010
# Epoch 27/300
# 219/219 [==============================] - 4s 17ms/step - loss: 423.3381 - root_mean_squared_error: 20.5752 - val_loss: 475.4508 - val_root_mean_squared_error: 21.8048 - lr: 0.0010
# Epoch 28/300
# 219/219 [==============================] - 7s 30ms/step - loss: 421.5728 - root_mean_squared_error: 20.5322 - val_loss: 471.3194 - val_root_mean_squared_error: 21.7099 - lr: 0.0010
# Epoch 29/300
# 219/219 [==============================] - 4s 17ms/step - loss: 423.2685 - root_mean_squared_error: 20.5735 - val_loss: 476.3008 - val_root_mean_squared_error: 21.8243 - lr: 0.0010
# Epoch 30/300
# 219/219 [==============================] - 5s 22ms/step - loss: 422.7122 - root_mean_squared_error: 20.5600 - val_loss: 475.9243 - val_root_mean_squared_error: 21.8157 - lr: 0.0010
# Epoch 31/300
# 219/219 [==============================] - 4s 20ms/step - loss: 421.5073 - root_mean_squared_error: 20.5306 - val_loss: 472.2503 - val_root_mean_squared_error: 21.7313 - lr: 0.0010
# Epoch 32/300
# 219/219 [==============================] - 4s 17ms/step - loss: 421.9762 - root_mean_squared_error: 20.5421 - val_loss: 474.0089 - val_root_mean_squared_error: 21.7717 - lr: 0.0010
# Epoch 33/300
# 219/219 [==============================] - 5s 22ms/step - loss: 419.7703 - root_mean_squared_error: 20.4883 - val_loss: 475.4501 - val_root_mean_squared_error: 21.8048 - lr: 0.0010
# Epoch 34/300
# 219/219 [==============================] - 4s 18ms/step - loss: 422.1193 - root_mean_squared_error: 20.5455 - val_loss: 474.8098 - val_root_mean_squared_error: 21.7901 - lr: 0.0010
# Epoch 35/300
# 219/219 [==============================] - 4s 16ms/step - loss: 420.3332 - root_mean_squared_error: 20.5020 - val_loss: 471.5890 - val_root_mean_squared_error: 21.7161 - lr: 0.0010
# Epoch 36/300
# 219/219 [==============================] - 5s 21ms/step - loss: 419.6094 - root_mean_squared_error: 20.4844 - val_loss: 479.5377 - val_root_mean_squared_error: 21.8983 - lr: 0.0010
# Epoch 37/300
# 219/219 [==============================] - 5s 21ms/step - loss: 418.0180 - root_mean_squared_error: 20.4455 - val_loss: 472.9890 - val_root_mean_squared_error: 21.7483 - lr: 0.0010
# Epoch 38/300
# 219/219 [==============================] - 6s 27ms/step - loss: 417.0722 - root_mean_squared_error: 20.4223 - val_loss: 468.6801 - val_root_mean_squared_error: 21.6490 - lr: 0.0010
# Epoch 39/300
# 219/219 [==============================] - 4s 17ms/step - loss: 418.1983 - root_mean_squared_error: 20.4499 - val_loss: 468.9742 - val_root_mean_squared_error: 21.6558 - lr: 0.0010
# Epoch 40/300
# 219/219 [==============================] - 4s 18ms/step - loss: 417.1143 - root_mean_squared_error: 20.4234 - val_loss: 477.6185 - val_root_mean_squared_error: 21.8545 - lr: 0.0010
# Epoch 41/300
# 219/219 [==============================] - 5s 24ms/step - loss: 416.3113 - root_mean_squared_error: 20.4037 - val_loss: 471.3344 - val_root_mean_squared_error: 21.7102 - lr: 0.0010
# Epoch 42/300
# 219/219 [==============================] - 4s 18ms/step - loss: 415.4134 - root_mean_squared_error: 20.3817 - val_loss: 473.5186 - val_root_mean_squared_error: 21.7605 - lr: 0.0010
# Epoch 43/300
# 219/219 [==============================] - 4s 17ms/step - loss: 416.0334 - root_mean_squared_error: 20.3969 - val_loss: 471.7679 - val_root_mean_squared_error: 21.7202 - lr: 0.0010
# Epoch 44/300
# 219/219 [==============================] - 5s 24ms/step - loss: 414.7398 - root_mean_squared_error: 20.3652 - val_loss: 470.7379 - val_root_mean_squared_error: 21.6965 - lr: 0.0010
# Epoch 45/300
# 219/219 [==============================] - 4s 17ms/step - loss: 414.4778 - root_mean_squared_error: 20.3587 - val_loss: 471.2621 - val_root_mean_squared_error: 21.7086 - lr: 0.0010
# Epoch 46/300
# 219/219 [==============================] - 4s 20ms/step - loss: 415.7588 - root_mean_squared_error: 20.3902 - val_loss: 476.7025 - val_root_mean_squared_error: 21.8335 - lr: 0.0010
# Epoch 47/300
# 219/219 [==============================] - 4s 18ms/step - loss: 414.7437 - root_mean_squared_error: 20.3653 - val_loss: 473.1215 - val_root_mean_squared_error: 21.7514 - lr: 0.0010
# Epoch 48/300
# 219/219 [==============================] - 4s 17ms/step - loss: 412.5218 - root_mean_squared_error: 20.3106 - val_loss: 469.8415 - val_root_mean_squared_error: 21.6758 - lr: 0.0010
# Epoch 49/300
# 219/219 [==============================] - 8s 37ms/step - loss: 408.1986 - root_mean_squared_error: 20.2039 - val_loss: 465.9274 - val_root_mean_squared_error: 21.5854 - lr: 1.0000e-04
# Epoch 50/300
# 219/219 [==============================] - 6s 28ms/step - loss: 406.0344 - root_mean_squared_error: 20.1503 - val_loss: 465.0176 - val_root_mean_squared_error: 21.5643 - lr: 1.0000e-04
# Epoch 51/300
# 219/219 [==============================] - 7s 32ms/step - loss: 404.7065 - root_mean_squared_error: 20.1173 - val_loss: 464.9485 - val_root_mean_squared_error: 21.5627 - lr: 1.0000e-04
# Epoch 52/300
# 219/219 [==============================] - 4s 17ms/step - loss: 404.3260 - root_mean_squared_error: 20.1079 - val_loss: 465.9491 - val_root_mean_squared_error: 21.5859 - lr: 1.0000e-04
# Epoch 53/300
# 219/219 [==============================] - 5s 25ms/step - loss: 403.7508 - root_mean_squared_error: 20.0936 - val_loss: 465.3977 - val_root_mean_squared_error: 21.5731 - lr: 1.0000e-04
# Epoch 54/300
# 219/219 [==============================] - 4s 18ms/step - loss: 403.9648 - root_mean_squared_error: 20.0989 - val_loss: 466.7945 - val_root_mean_squared_error: 21.6054 - lr: 1.0000e-04
# Epoch 55/300
# 219/219 [==============================] - 5s 21ms/step - loss: 404.1875 - root_mean_squared_error: 20.1044 - val_loss: 465.9837 - val_root_mean_squared_error: 21.5867 - lr: 1.0000e-04
# Epoch 56/300
# 219/219 [==============================] - 4s 20ms/step - loss: 403.5681 - root_mean_squared_error: 20.0890 - val_loss: 465.0066 - val_root_mean_squared_error: 21.5640 - lr: 1.0000e-04
# Epoch 57/300
# 219/219 [==============================] - 4s 17ms/step - loss: 402.5607 - root_mean_squared_error: 20.0639 - val_loss: 465.6193 - val_root_mean_squared_error: 21.5782 - lr: 1.0000e-04
# Epoch 58/300
# 219/219 [==============================] - 7s 33ms/step - loss: 401.0850 - root_mean_squared_error: 20.0271 - val_loss: 464.0654 - val_root_mean_squared_error: 21.5422 - lr: 1.0000e-04
# Epoch 59/300
# 219/219 [==============================] - 4s 18ms/step - loss: 401.2278 - root_mean_squared_error: 20.0307 - val_loss: 465.4235 - val_root_mean_squared_error: 21.5737 - lr: 1.0000e-04
# Epoch 60/300
# 219/219 [==============================] - 5s 25ms/step - loss: 402.0014 - root_mean_squared_error: 20.0500 - val_loss: 466.1190 - val_root_mean_squared_error: 21.5898 - lr: 1.0000e-04
# Epoch 61/300
# 219/219 [==============================] - 4s 17ms/step - loss: 401.1637 - root_mean_squared_error: 20.0291 - val_loss: 464.9496 - val_root_mean_squared_error: 21.5627 - lr: 1.0000e-04
# Epoch 62/300
# 219/219 [==============================] - 5s 23ms/step - loss: 398.9973 - root_mean_squared_error: 19.9749 - val_loss: 465.4829 - val_root_mean_squared_error: 21.5751 - lr: 1.0000e-04
# Epoch 63/300
# 219/219 [==============================] - 6s 27ms/step - loss: 402.7383 - root_mean_squared_error: 20.0683 - val_loss: 463.9519 - val_root_mean_squared_error: 21.5395 - lr: 1.0000e-04
# Epoch 64/300
# 219/219 [==============================] - 5s 25ms/step - loss: 399.5051 - root_mean_squared_error: 19.9876 - val_loss: 464.4078 - val_root_mean_squared_error: 21.5501 - lr: 1.0000e-04
# Epoch 65/300
# 219/219 [==============================] - 4s 17ms/step - loss: 400.8069 - root_mean_squared_error: 20.0202 - val_loss: 464.9634 - val_root_mean_squared_error: 21.5630 - lr: 1.0000e-04
# Epoch 66/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.1040 - root_mean_squared_error: 20.0026 - val_loss: 464.7460 - val_root_mean_squared_error: 21.5580 - lr: 1.0000e-04
# Epoch 67/300
# 219/219 [==============================] - 8s 37ms/step - loss: 401.1645 - root_mean_squared_error: 20.0291 - val_loss: 463.8352 - val_root_mean_squared_error: 21.5368 - lr: 1.0000e-04
# Epoch 68/300
# 219/219 [==============================] - 4s 17ms/step - loss: 401.3099 - root_mean_squared_error: 20.0327 - val_loss: 464.0157 - val_root_mean_squared_error: 21.5410 - lr: 1.0000e-04
# Epoch 69/300
# 219/219 [==============================] - 5s 24ms/step - loss: 400.9245 - root_mean_squared_error: 20.0231 - val_loss: 465.0751 - val_root_mean_squared_error: 21.5656 - lr: 1.0000e-04
# Epoch 70/300
# 219/219 [==============================] - 4s 18ms/step - loss: 401.0681 - root_mean_squared_error: 20.0267 - val_loss: 464.0623 - val_root_mean_squared_error: 21.5421 - lr: 1.0000e-04
# Epoch 71/300
# 219/219 [==============================] - 7s 31ms/step - loss: 399.2175 - root_mean_squared_error: 19.9804 - val_loss: 463.1586 - val_root_mean_squared_error: 21.5211 - lr: 1.0000e-04
# Epoch 72/300
# 219/219 [==============================] - 4s 17ms/step - loss: 397.4991 - root_mean_squared_error: 19.9374 - val_loss: 464.0143 - val_root_mean_squared_error: 21.5410 - lr: 1.0000e-04
# Epoch 73/300
# 219/219 [==============================] - 4s 17ms/step - loss: 399.3450 - root_mean_squared_error: 19.9836 - val_loss: 463.9754 - val_root_mean_squared_error: 21.5401 - lr: 1.0000e-04
# Epoch 74/300
# 219/219 [==============================] - 5s 23ms/step - loss: 399.4675 - root_mean_squared_error: 19.9867 - val_loss: 463.2110 - val_root_mean_squared_error: 21.5223 - lr: 1.0000e-04
# Epoch 75/300
# 219/219 [==============================] - 4s 20ms/step - loss: 399.7324 - root_mean_squared_error: 19.9933 - val_loss: 463.4733 - val_root_mean_squared_error: 21.5284 - lr: 1.0000e-04
# Epoch 76/300
# 219/219 [==============================] - 4s 17ms/step - loss: 399.3293 - root_mean_squared_error: 19.9832 - val_loss: 463.3775 - val_root_mean_squared_error: 21.5262 - lr: 1.0000e-04
# Epoch 77/300
# 219/219 [==============================] - 5s 25ms/step - loss: 400.6048 - root_mean_squared_error: 20.0151 - val_loss: 463.4182 - val_root_mean_squared_error: 21.5271 - lr: 1.0000e-04
# Epoch 78/300
# 219/219 [==============================] - 4s 18ms/step - loss: 399.1426 - root_mean_squared_error: 19.9786 - val_loss: 464.1232 - val_root_mean_squared_error: 21.5435 - lr: 1.0000e-04
# Epoch 79/300
# 219/219 [==============================] - 6s 28ms/step - loss: 399.7614 - root_mean_squared_error: 19.9940 - val_loss: 462.7954 - val_root_mean_squared_error: 21.5127 - lr: 1.0000e-04
# Epoch 80/300
# 219/219 [==============================] - 4s 17ms/step - loss: 398.6732 - root_mean_squared_error: 19.9668 - val_loss: 463.7901 - val_root_mean_squared_error: 21.5358 - lr: 1.0000e-04
# Epoch 81/300
# 219/219 [==============================] - 4s 20ms/step - loss: 398.6710 - root_mean_squared_error: 19.9667 - val_loss: 463.1911 - val_root_mean_squared_error: 21.5219 - lr: 1.0000e-04
# Epoch 82/300
# 219/219 [==============================] - 7s 32ms/step - loss: 398.3055 - root_mean_squared_error: 19.9576 - val_loss: 462.2908 - val_root_mean_squared_error: 21.5009 - lr: 1.0000e-04
# Epoch 83/300
# 219/219 [==============================] - 4s 17ms/step - loss: 398.4199 - root_mean_squared_error: 19.9605 - val_loss: 463.0782 - val_root_mean_squared_error: 21.5193 - lr: 1.0000e-04
# Epoch 84/300
# 219/219 [==============================] - 6s 25ms/step - loss: 397.7393 - root_mean_squared_error: 19.9434 - val_loss: 462.5561 - val_root_mean_squared_error: 21.5071 - lr: 1.0000e-04
# Epoch 85/300
# 219/219 [==============================] - 4s 17ms/step - loss: 396.8011 - root_mean_squared_error: 19.9199 - val_loss: 462.8491 - val_root_mean_squared_error: 21.5139 - lr: 1.0000e-04
# Epoch 86/300
# 219/219 [==============================] - 5s 21ms/step - loss: 398.8797 - root_mean_squared_error: 19.9720 - val_loss: 463.7302 - val_root_mean_squared_error: 21.5344 - lr: 1.0000e-04
# Epoch 87/300
# 219/219 [==============================] - 4s 19ms/step - loss: 397.4075 - root_mean_squared_error: 19.9351 - val_loss: 462.9009 - val_root_mean_squared_error: 21.5151 - lr: 1.0000e-04
# Epoch 88/300
# 219/219 [==============================] - 4s 17ms/step - loss: 397.8100 - root_mean_squared_error: 19.9452 - val_loss: 462.9729 - val_root_mean_squared_error: 21.5168 - lr: 1.0000e-04
# Epoch 89/300
# 219/219 [==============================] - 5s 25ms/step - loss: 399.0374 - root_mean_squared_error: 19.9759 - val_loss: 462.6436 - val_root_mean_squared_error: 21.5092 - lr: 1.0000e-04
# Epoch 90/300
# 219/219 [==============================] - 7s 31ms/step - loss: 397.2314 - root_mean_squared_error: 19.9307 - val_loss: 461.7450 - val_root_mean_squared_error: 21.4883 - lr: 1.0000e-04
# Epoch 91/300
# 219/219 [==============================] - 4s 17ms/step - loss: 397.2511 - root_mean_squared_error: 19.9312 - val_loss: 463.7369 - val_root_mean_squared_error: 21.5345 - lr: 1.0000e-04
# Epoch 92/300
# 219/219 [==============================] - 5s 21ms/step - loss: 397.5923 - root_mean_squared_error: 19.9397 - val_loss: 462.7489 - val_root_mean_squared_error: 21.5116 - lr: 1.0000e-04
# Epoch 93/300
# 219/219 [==============================] - 5s 21ms/step - loss: 397.8713 - root_mean_squared_error: 19.9467 - val_loss: 463.1673 - val_root_mean_squared_error: 21.5213 - lr: 1.0000e-04
# Epoch 94/300
# 219/219 [==============================] - 4s 17ms/step - loss: 397.6515 - root_mean_squared_error: 19.9412 - val_loss: 463.7582 - val_root_mean_squared_error: 21.5350 - lr: 1.0000e-04
# Epoch 95/300
# 219/219 [==============================] - 5s 25ms/step - loss: 397.5032 - root_mean_squared_error: 19.9375 - val_loss: 463.7498 - val_root_mean_squared_error: 21.5349 - lr: 1.0000e-04
# Epoch 96/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.6779 - root_mean_squared_error: 19.8917 - val_loss: 462.2265 - val_root_mean_squared_error: 21.4995 - lr: 1.0000e-04
# Epoch 97/300
# 219/219 [==============================] - 4s 17ms/step - loss: 398.2148 - root_mean_squared_error: 19.9553 - val_loss: 463.9061 - val_root_mean_squared_error: 21.5385 - lr: 1.0000e-04
# Epoch 98/300
# 219/219 [==============================] - 5s 23ms/step - loss: 398.3676 - root_mean_squared_error: 19.9591 - val_loss: 462.0024 - val_root_mean_squared_error: 21.4942 - lr: 1.0000e-04
# Epoch 99/300
# 219/219 [==============================] - 4s 17ms/step - loss: 396.6316 - root_mean_squared_error: 19.9156 - val_loss: 464.2195 - val_root_mean_squared_error: 21.5458 - lr: 1.0000e-04
# Epoch 100/300
# 219/219 [==============================] - 4s 17ms/step - loss: 396.0434 - root_mean_squared_error: 19.9008 - val_loss: 463.2340 - val_root_mean_squared_error: 21.5229 - lr: 1.0000e-04
# Epoch 101/300
# 219/219 [==============================] - 7s 32ms/step - loss: 396.6776 - root_mean_squared_error: 19.9168 - val_loss: 461.3417 - val_root_mean_squared_error: 21.4789 - lr: 1.0000e-05
# Epoch 102/300
# 219/219 [==============================] - 7s 34ms/step - loss: 394.6849 - root_mean_squared_error: 19.8667 - val_loss: 461.1324 - val_root_mean_squared_error: 21.4740 - lr: 1.0000e-05
# Epoch 103/300
# 219/219 [==============================] - 4s 17ms/step - loss: 395.4694 - root_mean_squared_error: 19.8864 - val_loss: 461.3178 - val_root_mean_squared_error: 21.4783 - lr: 1.0000e-05
# Epoch 104/300
# 219/219 [==============================] - 4s 20ms/step - loss: 395.7662 - root_mean_squared_error: 19.8939 - val_loss: 461.4562 - val_root_mean_squared_error: 21.4815 - lr: 1.0000e-05
# Epoch 105/300
# 219/219 [==============================] - 4s 19ms/step - loss: 395.9653 - root_mean_squared_error: 19.8989 - val_loss: 461.4077 - val_root_mean_squared_error: 21.4804 - lr: 1.0000e-05
# Epoch 106/300
# 219/219 [==============================] - 4s 17ms/step - loss: 397.1518 - root_mean_squared_error: 19.9287 - val_loss: 461.2482 - val_root_mean_squared_error: 21.4767 - lr: 1.0000e-05
# Epoch 107/300
# 219/219 [==============================] - 5s 25ms/step - loss: 395.2446 - root_mean_squared_error: 19.8808 - val_loss: 461.5017 - val_root_mean_squared_error: 21.4826 - lr: 1.0000e-05
# Epoch 108/300
# 219/219 [==============================] - 4s 17ms/step - loss: 394.8844 - root_mean_squared_error: 19.8717 - val_loss: 461.3223 - val_root_mean_squared_error: 21.4784 - lr: 1.0000e-05
# Epoch 109/300
# 219/219 [==============================] - 5s 24ms/step - loss: 396.3543 - root_mean_squared_error: 19.9086 - val_loss: 461.4043 - val_root_mean_squared_error: 21.4803 - lr: 1.0000e-05
# Epoch 110/300
# 219/219 [==============================] - 5s 22ms/step - loss: 394.7091 - root_mean_squared_error: 19.8673 - val_loss: 461.3705 - val_root_mean_squared_error: 21.4795 - lr: 1.0000e-05
# Epoch 111/300
# 219/219 [==============================] - 4s 19ms/step - loss: 394.9454 - root_mean_squared_error: 19.8732 - val_loss: 461.3136 - val_root_mean_squared_error: 21.4782 - lr: 1.0000e-05
# Epoch 112/300
# 219/219 [==============================] - 6s 27ms/step - loss: 396.1205 - root_mean_squared_error: 19.9028 - val_loss: 461.0974 - val_root_mean_squared_error: 21.4732 - lr: 1.0000e-05
# Epoch 113/300
# 219/219 [==============================] - 4s 17ms/step - loss: 394.8167 - root_mean_squared_error: 19.8700 - val_loss: 461.1157 - val_root_mean_squared_error: 21.4736 - lr: 1.0000e-05
# Epoch 114/300
# 219/219 [==============================] - 4s 19ms/step - loss: 396.8586 - root_mean_squared_error: 19.9213 - val_loss: 461.4779 - val_root_mean_squared_error: 21.4820 - lr: 1.0000e-05
# Epoch 115/300
# 219/219 [==============================] - 4s 19ms/step - loss: 397.1902 - root_mean_squared_error: 19.9296 - val_loss: 461.1196 - val_root_mean_squared_error: 21.4737 - lr: 1.0000e-05
# Epoch 116/300
# 219/219 [==============================] - 4s 17ms/step - loss: 395.7188 - root_mean_squared_error: 19.8927 - val_loss: 461.2086 - val_root_mean_squared_error: 21.4758 - lr: 1.0000e-05
# Epoch 117/300
# 219/219 [==============================] - 5s 22ms/step - loss: 394.5203 - root_mean_squared_error: 19.8625 - val_loss: 461.3158 - val_root_mean_squared_error: 21.4783 - lr: 1.0000e-05
# Epoch 118/300
# 219/219 [==============================] - 4s 19ms/step - loss: 396.3162 - root_mean_squared_error: 19.9077 - val_loss: 461.3216 - val_root_mean_squared_error: 21.4784 - lr: 1.0000e-05
# Epoch 119/300
# 219/219 [==============================] - 4s 18ms/step - loss: 396.1620 - root_mean_squared_error: 19.9038 - val_loss: 461.2476 - val_root_mean_squared_error: 21.4767 - lr: 1.0000e-05
# Epoch 120/300
# 219/219 [==============================] - 5s 25ms/step - loss: 396.4847 - root_mean_squared_error: 19.9119 - val_loss: 461.3140 - val_root_mean_squared_error: 21.4782 - lr: 1.0000e-05
# Epoch 121/300
# 219/219 [==============================] - 4s 19ms/step - loss: 396.7986 - root_mean_squared_error: 19.9198 - val_loss: 461.2492 - val_root_mean_squared_error: 21.4767 - lr: 1.0000e-05
# Epoch 122/300
# 219/219 [==============================] - 6s 26ms/step - loss: 396.0739 - root_mean_squared_error: 19.9016 - val_loss: 461.1702 - val_root_mean_squared_error: 21.4749 - lr: 1.0000e-05
# Epoch 123/300
# 219/219 [==============================] - 4s 18ms/step - loss: 396.2828 - root_mean_squared_error: 19.9069 - val_loss: 461.2019 - val_root_mean_squared_error: 21.4756 - lr: 1.0000e-06
# Epoch 124/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.6275 - root_mean_squared_error: 19.8904 - val_loss: 461.2073 - val_root_mean_squared_error: 21.4757 - lr: 1.0000e-06
# Epoch 125/300
# 219/219 [==============================] - 5s 25ms/step - loss: 394.5541 - root_mean_squared_error: 19.8634 - val_loss: 461.2112 - val_root_mean_squared_error: 21.4758 - lr: 1.0000e-06
# Epoch 126/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.7213 - root_mean_squared_error: 19.8927 - val_loss: 461.2086 - val_root_mean_squared_error: 21.4758 - lr: 1.0000e-06
# Epoch 127/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.6064 - root_mean_squared_error: 19.8899 - val_loss: 461.2111 - val_root_mean_squared_error: 21.4758 - lr: 1.0000e-06
# Epoch 128/300
# 219/219 [==============================] - 5s 23ms/step - loss: 394.6727 - root_mean_squared_error: 19.8664 - val_loss: 461.2325 - val_root_mean_squared_error: 21.4763 - lr: 1.0000e-06
# Epoch 129/300
# 219/219 [==============================] - 4s 18ms/step - loss: 396.2614 - root_mean_squared_error: 19.9063 - val_loss: 461.2576 - val_root_mean_squared_error: 21.4769 - lr: 1.0000e-06
# Epoch 130/300
# 219/219 [==============================] - 6s 26ms/step - loss: 396.6544 - root_mean_squared_error: 19.9162 - val_loss: 461.2617 - val_root_mean_squared_error: 21.4770 - lr: 1.0000e-06
# Epoch 131/300
# 219/219 [==============================] - 4s 19ms/step - loss: 396.8872 - root_mean_squared_error: 19.9220 - val_loss: 461.2584 - val_root_mean_squared_error: 21.4769 - lr: 1.0000e-06
# Epoch 132/300
# 219/219 [==============================] - 4s 19ms/step - loss: 395.7491 - root_mean_squared_error: 19.8934 - val_loss: 461.2350 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-06
# Epoch 133/300
# 219/219 [==============================] - 6s 25ms/step - loss: 395.8823 - root_mean_squared_error: 19.8968 - val_loss: 461.2369 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-07
# Epoch 134/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.3131 - root_mean_squared_error: 19.8825 - val_loss: 461.2389 - val_root_mean_squared_error: 21.4765 - lr: 1.0000e-07
# Epoch 135/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.3787 - root_mean_squared_error: 19.8841 - val_loss: 461.2365 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-07
# Epoch 136/300
# 219/219 [==============================] - 6s 26ms/step - loss: 394.9751 - root_mean_squared_error: 19.8740 - val_loss: 461.2358 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-07
# Epoch 137/300
# 219/219 [==============================] - 4s 18ms/step - loss: 396.8982 - root_mean_squared_error: 19.9223 - val_loss: 461.2387 - val_root_mean_squared_error: 21.4765 - lr: 1.0000e-07
# Epoch 138/300
# 219/219 [==============================] - 4s 20ms/step - loss: 394.4710 - root_mean_squared_error: 19.8613 - val_loss: 461.2332 - val_root_mean_squared_error: 21.4763 - lr: 1.0000e-07
# Epoch 139/300
# 219/219 [==============================] - 4s 18ms/step - loss: 393.5687 - root_mean_squared_error: 19.8386 - val_loss: 461.2333 - val_root_mean_squared_error: 21.4763 - lr: 1.0000e-07
# Epoch 140/300
# 219/219 [==============================] - 5s 25ms/step - loss: 396.4370 - root_mean_squared_error: 19.9107 - val_loss: 461.2390 - val_root_mean_squared_error: 21.4765 - lr: 1.0000e-07
# Epoch 141/300
# 219/219 [==============================] - 4s 18ms/step - loss: 394.9578 - root_mean_squared_error: 19.8735 - val_loss: 461.2384 - val_root_mean_squared_error: 21.4765 - lr: 1.0000e-07
# Epoch 142/300
# 219/219 [==============================] - 4s 18ms/step - loss: 395.6041 - root_mean_squared_error: 19.8898 - val_loss: 461.2354 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-07
# Epoch 143/300
# 219/219 [==============================] - 6s 25ms/step - loss: 394.5046 - root_mean_squared_error: 19.8621 - val_loss: 461.2351 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-08
# Epoch 144/300
# 219/219 [==============================] - 4s 19ms/step - loss: 395.2769 - root_mean_squared_error: 19.8816 - val_loss: 461.2350 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-08
# Epoch 145/300
# 219/219 [==============================] - 4s 19ms/step - loss: 394.7207 - root_mean_squared_error: 19.8676 - val_loss: 461.2349 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-08
# Epoch 146/300
# 219/219 [==============================] - 5s 25ms/step - loss: 396.8452 - root_mean_squared_error: 19.9210 - val_loss: 461.2350 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-08
# Epoch 147/300
# 219/219 [==============================] - 4s 18ms/step - loss: 394.0417 - root_mean_squared_error: 19.8505 - val_loss: 461.2348 - val_root_mean_squared_error: 21.4764 - lr: 1.0000e-08
# Evaluating on patient_id: 559
# all rolling: 2420
# 2267 size before reduction
# 2267 size after reduction
# 22 windows with too many nans
# 120 windows with empty labels
# all rolling: 2876
# 2482 size before reduction
# 2482 size after reduction
# 34 windows with too many nans
# 349 windows with empty labels
# Evaluating on patient_id: 563
# all rolling: 2627
# 2481 size before reduction
# 2481 size after reduction
# 33 windows with too many nans
# 102 windows with empty labels
# all rolling: 2814
# 2559 size before reduction
# 2559 size after reduction
# 10 windows with too many nans
# 234 windows with empty labels
# Evaluating on patient_id: 570
# all rolling: 2362
# 2193 size before reduction
# 2193 size after reduction
# 25 windows with too many nans
# 133 windows with empty labels
# all rolling: 2880
# 2727 size before reduction
# 2727 size after reduction
# 20 windows with too many nans
# 122 windows with empty labels
# Evaluating on patient_id: 575
# all rolling: 2621
# 2432 size before reduction
# 2432 size after reduction
# 23 windows with too many nans
# 155 windows with empty labels
# all rolling: 2745
# 2575 size before reduction
# 2575 size after reduction
# 15 windows with too many nans
# 144 windows with empty labels
# Evaluating on patient_id: 588
# all rolling: 2650
# 2619 size before reduction
# 2619 size after reduction
# 5 windows with too many nans
# 15 windows with empty labels
# all rolling: 2880
# 2777 size before reduction
# 2777 size after reduction
# 8 windows with too many nans
# 84 windows with empty labels
# Evaluating on patient_id: 591
# all rolling: 2592
# 2518 size before reduction
# 2518 size after reduction
# 12 windows with too many nans
# 51 windows with empty labels
# all rolling: 2847
# 2743 size before reduction
# 2743 size after reduction
# 10 windows with too many nans
# 83 windows with empty labels

# %%
test_errs
# Out:
# [('lmu_2018_ph30min', '559', 17.684860229492188),
#  ('lmu_2018_ph30min', '563', 17.447338104248047),
#  ('lmu_2018_ph30min', '570', 15.271833419799805),
#  ('lmu_2018_ph30min', '575', 21.337308883666992),
#  ('lmu_2018_ph30min', '588', 16.80900764465332),
#  ('lmu_2018_ph30min', '591', 20.4708309173584)]

# %% [markdown]
# ## Get statistics for multiple training runs

# %%
test_errs = [(f"{model}_0", patient, rmse) for model, patient, rmse in test_errs]

# %%
val_errs = [(f"{model}_0", patient, rmse) for model, patient, rmse in val_errs]

# %%
# 4 more runs
for i in range(1, 5):
    cur_val_errs, cur_test_errs = train_model(patient_windows_2018, f"{model_name}_{i}")
    test_errs.extend(cur_test_errs)
    val_errs.extend(cur_val_errs)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 6, 4)]               0         []
#
#  lmu_1 (LMU)                 (None, 72)                   81232     ['input_2[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    73        ['lmu_1[0][0]']
#
#  tf.__operators__.getitem_1  (None,)                      0         ['input_2[0][0]']
#   (SlicingOpLambda)
#
#  add_1 (Add)                 (None, 1)                    0         ['dense_1[0][0]',
#                                                                      'tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 81305 (317.60 KB)
# Trainable params: 81305 (317.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/300
# 219/219 [==============================] - 10s 38ms/step - loss: 557.2491 - root_mean_squared_error: 23.6061 - val_loss: 565.5477 - val_root_mean_squared_error: 23.7812 - lr: 0.0010
# Epoch 2/300
# 219/219 [==============================] - 6s 27ms/step - loss: 510.3300 - root_mean_squared_error: 22.5905 - val_loss: 540.3528 - val_root_mean_squared_error: 23.2455 - lr: 0.0010
# Epoch 3/300
# 219/219 [==============================] - 7s 31ms/step - loss: 491.6344 - root_mean_squared_error: 22.1728 - val_loss: 516.9894 - val_root_mean_squared_error: 22.7374 - lr: 0.0010
# Epoch 4/300
# 219/219 [==============================] - 7s 32ms/step - loss: 478.5973 - root_mean_squared_error: 21.8769 - val_loss: 507.9992 - val_root_mean_squared_error: 22.5388 - lr: 0.0010
# Epoch 5/300
# 219/219 [==============================] - 8s 38ms/step - loss: 469.2693 - root_mean_squared_error: 21.6626 - val_loss: 501.6234 - val_root_mean_squared_error: 22.3970 - lr: 0.0010
# Epoch 6/300
# 219/219 [==============================] - 6s 30ms/step - loss: 466.4726 - root_mean_squared_error: 21.5980 - val_loss: 496.2567 - val_root_mean_squared_error: 22.2768 - lr: 0.0010
# Epoch 7/300
# 219/219 [==============================] - 7s 30ms/step - loss: 459.7109 - root_mean_squared_error: 21.4409 - val_loss: 492.5976 - val_root_mean_squared_error: 22.1945 - lr: 0.0010
# Epoch 8/300
# 219/219 [==============================] - 7s 34ms/step - loss: 454.9516 - root_mean_squared_error: 21.3296 - val_loss: 489.8732 - val_root_mean_squared_error: 22.1331 - lr: 0.0010
# Epoch 9/300
# 219/219 [==============================] - 6s 29ms/step - loss: 452.7483 - root_mean_squared_error: 21.2779 - val_loss: 488.0041 - val_root_mean_squared_error: 22.0908 - lr: 0.0010
# Epoch 10/300
# 219/219 [==============================] - 5s 21ms/step - loss: 450.3755 - root_mean_squared_error: 21.2221 - val_loss: 489.0511 - val_root_mean_squared_error: 22.1145 - lr: 0.0010
# Epoch 11/300
# 219/219 [==============================] - 7s 30ms/step - loss: 448.1551 - root_mean_squared_error: 21.1697 - val_loss: 483.2898 - val_root_mean_squared_error: 21.9839 - lr: 0.0010
# Epoch 12/300
# 219/219 [==============================] - 8s 35ms/step - loss: 444.6371 - root_mean_squared_error: 21.0864 - val_loss: 481.4962 - val_root_mean_squared_error: 21.9430 - lr: 0.0010
# Epoch 13/300
# 219/219 [==============================] - 6s 28ms/step - loss: 442.3779 - root_mean_squared_error: 21.0328 - val_loss: 480.6525 - val_root_mean_squared_error: 21.9238 - lr: 0.0010
# Epoch 14/300
# 219/219 [==============================] - 6s 26ms/step - loss: 443.2092 - root_mean_squared_error: 21.0525 - val_loss: 480.8739 - val_root_mean_squared_error: 21.9288 - lr: 0.0010
# Epoch 15/300
# 219/219 [==============================] - 6s 27ms/step - loss: 440.3754 - root_mean_squared_error: 20.9851 - val_loss: 480.3496 - val_root_mean_squared_error: 21.9169 - lr: 0.0010
# Epoch 16/300
# 219/219 [==============================] - 6s 26ms/step - loss: 438.0509 - root_mean_squared_error: 20.9297 - val_loss: 482.9650 - val_root_mean_squared_error: 21.9765 - lr: 0.0010
# Epoch 17/300
# 219/219 [==============================] - 7s 30ms/step - loss: 437.8371 - root_mean_squared_error: 20.9246 - val_loss: 477.7905 - val_root_mean_squared_error: 21.8584 - lr: 0.0010
# Epoch 18/300
# 219/219 [==============================] - 7s 34ms/step - loss: 435.9590 - root_mean_squared_error: 20.8796 - val_loss: 477.5230 - val_root_mean_squared_error: 21.8523 - lr: 0.0010
# Epoch 19/300
# 219/219 [==============================] - 4s 17ms/step - loss: 433.4266 - root_mean_squared_error: 20.8189 - val_loss: 478.5440 - val_root_mean_squared_error: 21.8756 - lr: 0.0010
# Epoch 20/300
# 219/219 [==============================] - 8s 35ms/step - loss: 432.1318 - root_mean_squared_error: 20.7878 - val_loss: 476.2948 - val_root_mean_squared_error: 21.8242 - lr: 0.0010
# Epoch 21/300
# 219/219 [==============================] - 4s 18ms/step - loss: 431.6556 - root_mean_squared_error: 20.7763 - val_loss: 484.6191 - val_root_mean_squared_error: 22.0141 - lr: 0.0010
# Epoch 22/300
# 219/219 [==============================] - 6s 25ms/step - loss: 430.3492 - root_mean_squared_error: 20.7449 - val_loss: 483.5069 - val_root_mean_squared_error: 21.9888 - lr: 0.0010
# Epoch 23/300
# 219/219 [==============================] - 7s 30ms/step - loss: 428.9892 - root_mean_squared_error: 20.7121 - val_loss: 475.8686 - val_root_mean_squared_error: 21.8144 - lr: 0.0010
# Epoch 24/300
# 219/219 [==============================] - 6s 27ms/step - loss: 429.8187 - root_mean_squared_error: 20.7321 - val_loss: 475.7709 - val_root_mean_squared_error: 21.8122 - lr: 0.0010
# Epoch 25/300
# 219/219 [==============================] - 6s 27ms/step - loss: 428.8303 - root_mean_squared_error: 20.7082 - val_loss: 474.6699 - val_root_mean_squared_error: 21.7869 - lr: 0.0010
# Epoch 26/300
# 219/219 [==============================] - 5s 22ms/step - loss: 428.8546 - root_mean_squared_error: 20.7088 - val_loss: 476.0285 - val_root_mean_squared_error: 21.8181 - lr: 0.0010
# Epoch 27/300
# 219/219 [==============================] - 4s 19ms/step - loss: 428.2008 - root_mean_squared_error: 20.6930 - val_loss: 476.7537 - val_root_mean_squared_error: 21.8347 - lr: 0.0010
# Epoch 28/300
# 219/219 [==============================] - 6s 28ms/step - loss: 426.1075 - root_mean_squared_error: 20.6424 - val_loss: 473.6117 - val_root_mean_squared_error: 21.7626 - lr: 0.0010
# Epoch 29/300
# 219/219 [==============================] - 6s 26ms/step - loss: 425.7819 - root_mean_squared_error: 20.6345 - val_loss: 475.0715 - val_root_mean_squared_error: 21.7961 - lr: 0.0010
# Epoch 30/300
# 219/219 [==============================] - 4s 18ms/step - loss: 424.6237 - root_mean_squared_error: 20.6064 - val_loss: 474.5474 - val_root_mean_squared_error: 21.7841 - lr: 0.0010
# Epoch 31/300
# 219/219 [==============================] - 5s 21ms/step - loss: 424.2581 - root_mean_squared_error: 20.5975 - val_loss: 476.4090 - val_root_mean_squared_error: 21.8268 - lr: 0.0010
# Epoch 32/300
# 219/219 [==============================] - 5s 21ms/step - loss: 423.2752 - root_mean_squared_error: 20.5737 - val_loss: 476.9906 - val_root_mean_squared_error: 21.8401 - lr: 0.0010
# Epoch 33/300
# 219/219 [==============================] - 4s 17ms/step - loss: 422.7019 - root_mean_squared_error: 20.5597 - val_loss: 477.5957 - val_root_mean_squared_error: 21.8540 - lr: 0.0010
# Epoch 34/300
# 219/219 [==============================] - 8s 38ms/step - loss: 423.1750 - root_mean_squared_error: 20.5712 - val_loss: 472.7583 - val_root_mean_squared_error: 21.7430 - lr: 0.0010
# Epoch 35/300
# 219/219 [==============================] - 4s 18ms/step - loss: 422.3194 - root_mean_squared_error: 20.5504 - val_loss: 473.1594 - val_root_mean_squared_error: 21.7522 - lr: 0.0010
# Epoch 36/300
# 219/219 [==============================] - 7s 33ms/step - loss: 422.1182 - root_mean_squared_error: 20.5455 - val_loss: 471.8599 - val_root_mean_squared_error: 21.7223 - lr: 0.0010
# Epoch 37/300
# 219/219 [==============================] - 4s 17ms/step - loss: 421.4721 - root_mean_squared_error: 20.5298 - val_loss: 479.3107 - val_root_mean_squared_error: 21.8932 - lr: 0.0010
# Epoch 38/300
# 219/219 [==============================] - 6s 25ms/step - loss: 420.3483 - root_mean_squared_error: 20.5024 - val_loss: 472.2690 - val_root_mean_squared_error: 21.7317 - lr: 0.0010
# Epoch 39/300
# 219/219 [==============================] - 4s 17ms/step - loss: 420.5915 - root_mean_squared_error: 20.5083 - val_loss: 473.0652 - val_root_mean_squared_error: 21.7501 - lr: 0.0010
# Epoch 40/300
# 219/219 [==============================] - 6s 25ms/step - loss: 418.0463 - root_mean_squared_error: 20.4462 - val_loss: 473.1197 - val_root_mean_squared_error: 21.7513 - lr: 0.0010
# Epoch 41/300
# 219/219 [==============================] - 4s 18ms/step - loss: 420.6392 - root_mean_squared_error: 20.5095 - val_loss: 474.9033 - val_root_mean_squared_error: 21.7923 - lr: 0.0010
# Epoch 42/300
# 219/219 [==============================] - 4s 18ms/step - loss: 419.0485 - root_mean_squared_error: 20.4707 - val_loss: 473.8119 - val_root_mean_squared_error: 21.7672 - lr: 0.0010
# Epoch 43/300
# 219/219 [==============================] - 5s 24ms/step - loss: 420.2770 - root_mean_squared_error: 20.5007 - val_loss: 477.4538 - val_root_mean_squared_error: 21.8507 - lr: 0.0010
# Epoch 44/300
# 219/219 [==============================] - 4s 18ms/step - loss: 418.3845 - root_mean_squared_error: 20.4544 - val_loss: 477.2018 - val_root_mean_squared_error: 21.8449 - lr: 0.0010
# Epoch 45/300
# 219/219 [==============================] - 5s 23ms/step - loss: 417.6941 - root_mean_squared_error: 20.4376 - val_loss: 477.8386 - val_root_mean_squared_error: 21.8595 - lr: 0.0010
# Epoch 46/300
# 219/219 [==============================] - 4s 19ms/step - loss: 417.7175 - root_mean_squared_error: 20.4381 - val_loss: 472.1316 - val_root_mean_squared_error: 21.7286 - lr: 0.0010
# Epoch 47/300
# 219/219 [==============================] - 6s 28ms/step - loss: 414.4931 - root_mean_squared_error: 20.3591 - val_loss: 470.3235 - val_root_mean_squared_error: 21.6869 - lr: 1.0000e-04
# Epoch 48/300
# 219/219 [==============================] - 7s 34ms/step - loss: 412.3833 - root_mean_squared_error: 20.3072 - val_loss: 468.9651 - val_root_mean_squared_error: 21.6556 - lr: 1.0000e-04
# Epoch 49/300
# 219/219 [==============================] - 4s 18ms/step - loss: 410.5475 - root_mean_squared_error: 20.2620 - val_loss: 469.6628 - val_root_mean_squared_error: 21.6717 - lr: 1.0000e-04
# Epoch 50/300
# 219/219 [==============================] - 6s 25ms/step - loss: 410.5316 - root_mean_squared_error: 20.2616 - val_loss: 469.5872 - val_root_mean_squared_error: 21.6700 - lr: 1.0000e-04
# Epoch 51/300
# 219/219 [==============================] - 6s 29ms/step - loss: 408.7302 - root_mean_squared_error: 20.2171 - val_loss: 468.5667 - val_root_mean_squared_error: 21.6464 - lr: 1.0000e-04
# Epoch 52/300
# 219/219 [==============================] - 4s 18ms/step - loss: 406.8204 - root_mean_squared_error: 20.1698 - val_loss: 469.4794 - val_root_mean_squared_error: 21.6675 - lr: 1.0000e-04
# Epoch 53/300
# 219/219 [==============================] - 8s 35ms/step - loss: 407.3133 - root_mean_squared_error: 20.1820 - val_loss: 468.2448 - val_root_mean_squared_error: 21.6390 - lr: 1.0000e-04
# Epoch 54/300
# 219/219 [==============================] - 4s 18ms/step - loss: 406.5208 - root_mean_squared_error: 20.1624 - val_loss: 469.8911 - val_root_mean_squared_error: 21.6770 - lr: 1.0000e-04
# Epoch 55/300
# 219/219 [==============================] - 5s 24ms/step - loss: 406.7785 - root_mean_squared_error: 20.1688 - val_loss: 470.0672 - val_root_mean_squared_error: 21.6810 - lr: 1.0000e-04
# Epoch 56/300
# 219/219 [==============================] - 4s 17ms/step - loss: 405.5396 - root_mean_squared_error: 20.1380 - val_loss: 468.9432 - val_root_mean_squared_error: 21.6551 - lr: 1.0000e-04
# Epoch 57/300
# 219/219 [==============================] - 6s 26ms/step - loss: 406.1519 - root_mean_squared_error: 20.1532 - val_loss: 469.0959 - val_root_mean_squared_error: 21.6586 - lr: 1.0000e-04
# Epoch 58/300
# 219/219 [==============================] - 4s 18ms/step - loss: 406.1274 - root_mean_squared_error: 20.1526 - val_loss: 468.8080 - val_root_mean_squared_error: 21.6520 - lr: 1.0000e-04
# Epoch 59/300
# 219/219 [==============================] - 5s 24ms/step - loss: 406.2864 - root_mean_squared_error: 20.1565 - val_loss: 468.9770 - val_root_mean_squared_error: 21.6559 - lr: 1.0000e-04
# Epoch 60/300
# 219/219 [==============================] - 5s 22ms/step - loss: 406.0851 - root_mean_squared_error: 20.1516 - val_loss: 468.7334 - val_root_mean_squared_error: 21.6503 - lr: 1.0000e-04
# Epoch 61/300
# 219/219 [==============================] - 7s 31ms/step - loss: 405.3249 - root_mean_squared_error: 20.1327 - val_loss: 467.8380 - val_root_mean_squared_error: 21.6296 - lr: 1.0000e-04
# Epoch 62/300
# 219/219 [==============================] - 6s 26ms/step - loss: 406.6185 - root_mean_squared_error: 20.1648 - val_loss: 468.6581 - val_root_mean_squared_error: 21.6485 - lr: 1.0000e-04
# Epoch 63/300
# 219/219 [==============================] - 4s 18ms/step - loss: 405.3295 - root_mean_squared_error: 20.1328 - val_loss: 469.7393 - val_root_mean_squared_error: 21.6735 - lr: 1.0000e-04
# Epoch 64/300
# 219/219 [==============================] - 4s 17ms/step - loss: 404.1877 - root_mean_squared_error: 20.1044 - val_loss: 469.7770 - val_root_mean_squared_error: 21.6743 - lr: 1.0000e-04
# Epoch 65/300
# 219/219 [==============================] - 7s 31ms/step - loss: 404.7267 - root_mean_squared_error: 20.1178 - val_loss: 467.6091 - val_root_mean_squared_error: 21.6243 - lr: 1.0000e-04
# Epoch 66/300
# 219/219 [==============================] - 6s 25ms/step - loss: 404.1009 - root_mean_squared_error: 20.1023 - val_loss: 469.6448 - val_root_mean_squared_error: 21.6713 - lr: 1.0000e-04
# Epoch 67/300
# 219/219 [==============================] - 4s 18ms/step - loss: 404.2449 - root_mean_squared_error: 20.1058 - val_loss: 470.3116 - val_root_mean_squared_error: 21.6867 - lr: 1.0000e-04
# Epoch 68/300
# 219/219 [==============================] - 6s 26ms/step - loss: 404.9043 - root_mean_squared_error: 20.1222 - val_loss: 468.7317 - val_root_mean_squared_error: 21.6502 - lr: 1.0000e-04
# Epoch 69/300
# 219/219 [==============================] - 4s 17ms/step - loss: 404.6990 - root_mean_squared_error: 20.1171 - val_loss: 468.6783 - val_root_mean_squared_error: 21.6490 - lr: 1.0000e-04
# Epoch 70/300
# 219/219 [==============================] - 4s 18ms/step - loss: 404.4809 - root_mean_squared_error: 20.1117 - val_loss: 467.8511 - val_root_mean_squared_error: 21.6299 - lr: 1.0000e-04
# Epoch 71/300
# 219/219 [==============================] - 5s 24ms/step - loss: 404.4376 - root_mean_squared_error: 20.1106 - val_loss: 469.1170 - val_root_mean_squared_error: 21.6591 - lr: 1.0000e-04
# Epoch 72/300
# 219/219 [==============================] - 4s 17ms/step - loss: 404.1260 - root_mean_squared_error: 20.1029 - val_loss: 468.0443 - val_root_mean_squared_error: 21.6343 - lr: 1.0000e-04
# Epoch 73/300
# 219/219 [==============================] - 7s 32ms/step - loss: 404.2514 - root_mean_squared_error: 20.1060 - val_loss: 467.3949 - val_root_mean_squared_error: 21.6193 - lr: 1.0000e-04
# Epoch 74/300
# 219/219 [==============================] - 4s 17ms/step - loss: 403.2738 - root_mean_squared_error: 20.0817 - val_loss: 469.1508 - val_root_mean_squared_error: 21.6599 - lr: 1.0000e-04
# Epoch 75/300
# 219/219 [==============================] - 5s 23ms/step - loss: 403.3595 - root_mean_squared_error: 20.0838 - val_loss: 469.3394 - val_root_mean_squared_error: 21.6642 - lr: 1.0000e-04
# Epoch 76/300
# 219/219 [==============================] - 4s 19ms/step - loss: 404.1685 - root_mean_squared_error: 20.1039 - val_loss: 468.3917 - val_root_mean_squared_error: 21.6424 - lr: 1.0000e-04
# Epoch 77/300
# 219/219 [==============================] - 4s 17ms/step - loss: 404.3706 - root_mean_squared_error: 20.1090 - val_loss: 467.7018 - val_root_mean_squared_error: 21.6264 - lr: 1.0000e-04
# Epoch 78/300
# 219/219 [==============================] - 6s 26ms/step - loss: 403.0722 - root_mean_squared_error: 20.0767 - val_loss: 467.6537 - val_root_mean_squared_error: 21.6253 - lr: 1.0000e-04
# Epoch 79/300
# 219/219 [==============================] - 6s 27ms/step - loss: 401.8579 - root_mean_squared_error: 20.0464 - val_loss: 466.4500 - val_root_mean_squared_error: 21.5975 - lr: 1.0000e-04
# Epoch 80/300
# 219/219 [==============================] - 5s 21ms/step - loss: 402.5626 - root_mean_squared_error: 20.0640 - val_loss: 467.2338 - val_root_mean_squared_error: 21.6156 - lr: 1.0000e-04
# Epoch 81/300
# 219/219 [==============================] - 5s 21ms/step - loss: 404.0283 - root_mean_squared_error: 20.1005 - val_loss: 467.8449 - val_root_mean_squared_error: 21.6297 - lr: 1.0000e-04
# Epoch 82/300
# 219/219 [==============================] - 4s 18ms/step - loss: 402.3512 - root_mean_squared_error: 20.0587 - val_loss: 467.2075 - val_root_mean_squared_error: 21.6150 - lr: 1.0000e-04
# Epoch 83/300
# 219/219 [==============================] - 6s 26ms/step - loss: 401.6449 - root_mean_squared_error: 20.0411 - val_loss: 467.1783 - val_root_mean_squared_error: 21.6143 - lr: 1.0000e-04
# Epoch 84/300
# 219/219 [==============================] - 4s 18ms/step - loss: 403.4764 - root_mean_squared_error: 20.0867 - val_loss: 466.8297 - val_root_mean_squared_error: 21.6062 - lr: 1.0000e-04
# Epoch 85/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.7224 - root_mean_squared_error: 20.0181 - val_loss: 467.2511 - val_root_mean_squared_error: 21.6160 - lr: 1.0000e-04
# Epoch 86/300
# 219/219 [==============================] - 5s 24ms/step - loss: 403.1869 - root_mean_squared_error: 20.0795 - val_loss: 466.9527 - val_root_mean_squared_error: 21.6091 - lr: 1.0000e-04
# Epoch 87/300
# 219/219 [==============================] - 7s 34ms/step - loss: 403.4174 - root_mean_squared_error: 20.0853 - val_loss: 465.9088 - val_root_mean_squared_error: 21.5849 - lr: 1.0000e-04
# Epoch 88/300
# 219/219 [==============================] - 4s 18ms/step - loss: 403.1562 - root_mean_squared_error: 20.0788 - val_loss: 466.1653 - val_root_mean_squared_error: 21.5909 - lr: 1.0000e-04
# Epoch 89/300
# 219/219 [==============================] - 6s 25ms/step - loss: 403.1936 - root_mean_squared_error: 20.0797 - val_loss: 466.8858 - val_root_mean_squared_error: 21.6075 - lr: 1.0000e-04
# Epoch 90/300
# 219/219 [==============================] - 4s 18ms/step - loss: 402.6918 - root_mean_squared_error: 20.0672 - val_loss: 466.9916 - val_root_mean_squared_error: 21.6100 - lr: 1.0000e-04
# Epoch 91/300
# 219/219 [==============================] - 6s 26ms/step - loss: 401.4813 - root_mean_squared_error: 20.0370 - val_loss: 466.1556 - val_root_mean_squared_error: 21.5906 - lr: 1.0000e-04
# Epoch 92/300
# 219/219 [==============================] - 4s 18ms/step - loss: 402.4894 - root_mean_squared_error: 20.0621 - val_loss: 466.5147 - val_root_mean_squared_error: 21.5989 - lr: 1.0000e-04
# Epoch 93/300
# 219/219 [==============================] - 4s 17ms/step - loss: 401.9089 - root_mean_squared_error: 20.0477 - val_loss: 468.0298 - val_root_mean_squared_error: 21.6340 - lr: 1.0000e-04
# Epoch 94/300
# 219/219 [==============================] - 6s 25ms/step - loss: 404.0484 - root_mean_squared_error: 20.1010 - val_loss: 466.5322 - val_root_mean_squared_error: 21.5994 - lr: 1.0000e-04
# Epoch 95/300
# 219/219 [==============================] - 4s 18ms/step - loss: 402.1669 - root_mean_squared_error: 20.0541 - val_loss: 466.8180 - val_root_mean_squared_error: 21.6060 - lr: 1.0000e-04
# Epoch 96/300
# 219/219 [==============================] - 5s 21ms/step - loss: 402.0002 - root_mean_squared_error: 20.0499 - val_loss: 467.6605 - val_root_mean_squared_error: 21.6255 - lr: 1.0000e-04
# Epoch 97/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.8782 - root_mean_squared_error: 20.0219 - val_loss: 467.0760 - val_root_mean_squared_error: 21.6119 - lr: 1.0000e-04
# Epoch 98/300
# 219/219 [==============================] - 8s 36ms/step - loss: 400.9939 - root_mean_squared_error: 20.0248 - val_loss: 465.0811 - val_root_mean_squared_error: 21.5657 - lr: 1.0000e-05
# Epoch 99/300
# 219/219 [==============================] - 6s 27ms/step - loss: 400.8716 - root_mean_squared_error: 20.0218 - val_loss: 464.9119 - val_root_mean_squared_error: 21.5618 - lr: 1.0000e-05
# Epoch 100/300
# 219/219 [==============================] - 7s 34ms/step - loss: 401.2754 - root_mean_squared_error: 20.0319 - val_loss: 464.7897 - val_root_mean_squared_error: 21.5590 - lr: 1.0000e-05
# Epoch 101/300
# 219/219 [==============================] - 4s 18ms/step - loss: 398.5406 - root_mean_squared_error: 19.9635 - val_loss: 465.0038 - val_root_mean_squared_error: 21.5639 - lr: 1.0000e-05
# Epoch 102/300
# 219/219 [==============================] - 8s 35ms/step - loss: 399.5636 - root_mean_squared_error: 19.9891 - val_loss: 464.7030 - val_root_mean_squared_error: 21.5570 - lr: 1.0000e-05
# Epoch 103/300
# 219/219 [==============================] - 6s 30ms/step - loss: 400.6388 - root_mean_squared_error: 20.0160 - val_loss: 464.6143 - val_root_mean_squared_error: 21.5549 - lr: 1.0000e-05
# Epoch 104/300
# 219/219 [==============================] - 9s 41ms/step - loss: 400.3445 - root_mean_squared_error: 20.0086 - val_loss: 464.5190 - val_root_mean_squared_error: 21.5527 - lr: 1.0000e-05
# Epoch 105/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.4157 - root_mean_squared_error: 20.0104 - val_loss: 464.7292 - val_root_mean_squared_error: 21.5576 - lr: 1.0000e-05
# Epoch 106/300
# 219/219 [==============================] - 6s 26ms/step - loss: 399.4794 - root_mean_squared_error: 19.9870 - val_loss: 464.7425 - val_root_mean_squared_error: 21.5579 - lr: 1.0000e-05
# Epoch 107/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.5224 - root_mean_squared_error: 20.0131 - val_loss: 464.7354 - val_root_mean_squared_error: 21.5577 - lr: 1.0000e-05
# Epoch 108/300
# 219/219 [==============================] - 7s 30ms/step - loss: 400.1406 - root_mean_squared_error: 20.0035 - val_loss: 464.3711 - val_root_mean_squared_error: 21.5493 - lr: 1.0000e-05
# Epoch 109/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.3247 - root_mean_squared_error: 20.0081 - val_loss: 464.4020 - val_root_mean_squared_error: 21.5500 - lr: 1.0000e-05
# Epoch 110/300
# 219/219 [==============================] - 6s 26ms/step - loss: 400.0671 - root_mean_squared_error: 20.0017 - val_loss: 464.5466 - val_root_mean_squared_error: 21.5533 - lr: 1.0000e-05
# Epoch 111/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.1456 - root_mean_squared_error: 20.0036 - val_loss: 464.5937 - val_root_mean_squared_error: 21.5544 - lr: 1.0000e-05
# Epoch 112/300
# 219/219 [==============================] - 4s 18ms/step - loss: 401.8661 - root_mean_squared_error: 20.0466 - val_loss: 464.5659 - val_root_mean_squared_error: 21.5538 - lr: 1.0000e-05
# Epoch 113/300
# 219/219 [==============================] - 6s 26ms/step - loss: 398.8056 - root_mean_squared_error: 19.9701 - val_loss: 464.6003 - val_root_mean_squared_error: 21.5546 - lr: 1.0000e-05
# Epoch 114/300
# 219/219 [==============================] - 4s 18ms/step - loss: 401.3266 - root_mean_squared_error: 20.0331 - val_loss: 464.7427 - val_root_mean_squared_error: 21.5579 - lr: 1.0000e-05
# Epoch 115/300
# 219/219 [==============================] - 5s 25ms/step - loss: 398.9398 - root_mean_squared_error: 19.9735 - val_loss: 464.6160 - val_root_mean_squared_error: 21.5550 - lr: 1.0000e-05
# Epoch 116/300
# 219/219 [==============================] - 5s 23ms/step - loss: 399.7040 - root_mean_squared_error: 19.9926 - val_loss: 464.6461 - val_root_mean_squared_error: 21.5557 - lr: 1.0000e-05
# Epoch 117/300
# 219/219 [==============================] - 5s 22ms/step - loss: 400.3038 - root_mean_squared_error: 20.0076 - val_loss: 464.4440 - val_root_mean_squared_error: 21.5510 - lr: 1.0000e-05
# Epoch 118/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.8554 - root_mean_squared_error: 19.9714 - val_loss: 464.4410 - val_root_mean_squared_error: 21.5509 - lr: 1.0000e-05
# Epoch 119/300
# 219/219 [==============================] - 6s 26ms/step - loss: 399.1514 - root_mean_squared_error: 19.9788 - val_loss: 464.5041 - val_root_mean_squared_error: 21.5524 - lr: 1.0000e-06
# Epoch 120/300
# 219/219 [==============================] - 4s 18ms/step - loss: 399.4425 - root_mean_squared_error: 19.9861 - val_loss: 464.5469 - val_root_mean_squared_error: 21.5534 - lr: 1.0000e-06
# Epoch 121/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.9696 - root_mean_squared_error: 19.9742 - val_loss: 464.6065 - val_root_mean_squared_error: 21.5547 - lr: 1.0000e-06
# Epoch 122/300
# 219/219 [==============================] - 6s 25ms/step - loss: 399.7055 - root_mean_squared_error: 19.9926 - val_loss: 464.6237 - val_root_mean_squared_error: 21.5551 - lr: 1.0000e-06
# Epoch 123/300
# 219/219 [==============================] - 5s 23ms/step - loss: 401.7467 - root_mean_squared_error: 20.0436 - val_loss: 464.6258 - val_root_mean_squared_error: 21.5552 - lr: 1.0000e-06
# Epoch 124/300
# 219/219 [==============================] - 5s 22ms/step - loss: 401.0212 - root_mean_squared_error: 20.0255 - val_loss: 464.5977 - val_root_mean_squared_error: 21.5545 - lr: 1.0000e-06
# Epoch 125/300
# 219/219 [==============================] - 4s 19ms/step - loss: 401.5589 - root_mean_squared_error: 20.0389 - val_loss: 464.6413 - val_root_mean_squared_error: 21.5555 - lr: 1.0000e-06
# Epoch 126/300
# 219/219 [==============================] - 6s 27ms/step - loss: 399.9092 - root_mean_squared_error: 19.9977 - val_loss: 464.6496 - val_root_mean_squared_error: 21.5557 - lr: 1.0000e-06
# Epoch 127/300
# 219/219 [==============================] - 4s 19ms/step - loss: 401.8283 - root_mean_squared_error: 20.0457 - val_loss: 464.6264 - val_root_mean_squared_error: 21.5552 - lr: 1.0000e-06
# Epoch 128/300
# 219/219 [==============================] - 4s 19ms/step - loss: 401.4205 - root_mean_squared_error: 20.0355 - val_loss: 464.6769 - val_root_mean_squared_error: 21.5564 - lr: 1.0000e-06
# Epoch 129/300
# 219/219 [==============================] - 6s 26ms/step - loss: 400.9645 - root_mean_squared_error: 20.0241 - val_loss: 464.6747 - val_root_mean_squared_error: 21.5563 - lr: 1.0000e-07
# Epoch 130/300
# 219/219 [==============================] - 5s 22ms/step - loss: 399.6502 - root_mean_squared_error: 19.9913 - val_loss: 464.6763 - val_root_mean_squared_error: 21.5564 - lr: 1.0000e-07
# Epoch 131/300
# 219/219 [==============================] - 5s 23ms/step - loss: 400.4945 - root_mean_squared_error: 20.0124 - val_loss: 464.6722 - val_root_mean_squared_error: 21.5563 - lr: 1.0000e-07
# Epoch 132/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.2162 - root_mean_squared_error: 20.0054 - val_loss: 464.6690 - val_root_mean_squared_error: 21.5562 - lr: 1.0000e-07
# Epoch 133/300
# 219/219 [==============================] - 5s 25ms/step - loss: 400.6177 - root_mean_squared_error: 20.0154 - val_loss: 464.6660 - val_root_mean_squared_error: 21.5561 - lr: 1.0000e-07
# Epoch 134/300
# 219/219 [==============================] - 4s 20ms/step - loss: 400.8427 - root_mean_squared_error: 20.0211 - val_loss: 464.6539 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-07
# Epoch 135/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.5871 - root_mean_squared_error: 20.0147 - val_loss: 464.6561 - val_root_mean_squared_error: 21.5559 - lr: 1.0000e-07
# Epoch 136/300
# 219/219 [==============================] - 6s 25ms/step - loss: 398.0819 - root_mean_squared_error: 19.9520 - val_loss: 464.6524 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-07
# Epoch 137/300
# 219/219 [==============================] - 4s 19ms/step - loss: 399.4190 - root_mean_squared_error: 19.9855 - val_loss: 464.6484 - val_root_mean_squared_error: 21.5557 - lr: 1.0000e-07
# Epoch 138/300
# 219/219 [==============================] - 4s 19ms/step - loss: 401.1553 - root_mean_squared_error: 20.0289 - val_loss: 464.6534 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-07
# Epoch 139/300
# 219/219 [==============================] - 6s 27ms/step - loss: 399.6884 - root_mean_squared_error: 19.9922 - val_loss: 464.6535 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-08
# Epoch 140/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.9785 - root_mean_squared_error: 20.0244 - val_loss: 464.6536 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-08
# Epoch 141/300
# 219/219 [==============================] - 4s 18ms/step - loss: 399.3602 - root_mean_squared_error: 19.9840 - val_loss: 464.6534 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-08
# Epoch 142/300
# 219/219 [==============================] - 5s 25ms/step - loss: 400.0973 - root_mean_squared_error: 20.0024 - val_loss: 464.6535 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-08
# Epoch 143/300
# 219/219 [==============================] - 5s 25ms/step - loss: 400.7987 - root_mean_squared_error: 20.0200 - val_loss: 464.6534 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-08
# Evaluating on patient_id: 559
# Evaluating on patient_id: 563
# Evaluating on patient_id: 570
# Evaluating on patient_id: 575
# Evaluating on patient_id: 588
# Evaluating on patient_id: 591
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 6, 4)]               0         []
#
#  lmu_2 (LMU)                 (None, 72)                   81232     ['input_3[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    73        ['lmu_2[0][0]']
#
#  tf.__operators__.getitem_2  (None,)                      0         ['input_3[0][0]']
#   (SlicingOpLambda)
#
#  add_2 (Add)                 (None, 1)                    0         ['dense_2[0][0]',
#                                                                      'tf.__operators__.getitem_2[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 81305 (317.60 KB)
# Trainable params: 81305 (317.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/300
# 219/219 [==============================] - 10s 31ms/step - loss: 557.6523 - root_mean_squared_error: 23.6147 - val_loss: 570.5131 - val_root_mean_squared_error: 23.8854 - lr: 0.0010
# Epoch 2/300
# 219/219 [==============================] - 9s 42ms/step - loss: 512.4696 - root_mean_squared_error: 22.6378 - val_loss: 542.2203 - val_root_mean_squared_error: 23.2856 - lr: 0.0010
# Epoch 3/300
# 219/219 [==============================] - 7s 31ms/step - loss: 496.7126 - root_mean_squared_error: 22.2871 - val_loss: 527.9843 - val_root_mean_squared_error: 22.9779 - lr: 0.0010
# Epoch 4/300
# 219/219 [==============================] - 6s 29ms/step - loss: 483.9363 - root_mean_squared_error: 21.9986 - val_loss: 513.0090 - val_root_mean_squared_error: 22.6497 - lr: 0.0010
# Epoch 5/300
# 219/219 [==============================] - 8s 36ms/step - loss: 475.3889 - root_mean_squared_error: 21.8034 - val_loss: 506.6909 - val_root_mean_squared_error: 22.5098 - lr: 0.0010
# Epoch 6/300
# 219/219 [==============================] - 6s 29ms/step - loss: 468.7372 - root_mean_squared_error: 21.6503 - val_loss: 501.1876 - val_root_mean_squared_error: 22.3872 - lr: 0.0010
# Epoch 7/300
# 219/219 [==============================] - 6s 29ms/step - loss: 464.4573 - root_mean_squared_error: 21.5513 - val_loss: 496.8883 - val_root_mean_squared_error: 22.2910 - lr: 0.0010
# Epoch 8/300
# 219/219 [==============================] - 9s 39ms/step - loss: 459.8326 - root_mean_squared_error: 21.4437 - val_loss: 494.8620 - val_root_mean_squared_error: 22.2455 - lr: 0.0010
# Epoch 9/300
# 219/219 [==============================] - 6s 29ms/step - loss: 454.1815 - root_mean_squared_error: 21.3115 - val_loss: 490.6908 - val_root_mean_squared_error: 22.1515 - lr: 0.0010
# Epoch 10/300
# 219/219 [==============================] - 6s 28ms/step - loss: 452.9238 - root_mean_squared_error: 21.2820 - val_loss: 490.0222 - val_root_mean_squared_error: 22.1364 - lr: 0.0010
# Epoch 11/300
# 219/219 [==============================] - 4s 19ms/step - loss: 452.9356 - root_mean_squared_error: 21.2823 - val_loss: 490.9056 - val_root_mean_squared_error: 22.1564 - lr: 0.0010
# Epoch 12/300
# 219/219 [==============================] - 6s 28ms/step - loss: 448.0569 - root_mean_squared_error: 21.1674 - val_loss: 488.5521 - val_root_mean_squared_error: 22.1032 - lr: 0.0010
# Epoch 13/300
# 219/219 [==============================] - 8s 35ms/step - loss: 444.9768 - root_mean_squared_error: 21.0945 - val_loss: 487.5705 - val_root_mean_squared_error: 22.0810 - lr: 0.0010
# Epoch 14/300
# 219/219 [==============================] - 7s 34ms/step - loss: 445.0968 - root_mean_squared_error: 21.0973 - val_loss: 485.5087 - val_root_mean_squared_error: 22.0343 - lr: 0.0010
# Epoch 15/300
# 219/219 [==============================] - 7s 31ms/step - loss: 443.8857 - root_mean_squared_error: 21.0686 - val_loss: 483.0274 - val_root_mean_squared_error: 21.9779 - lr: 0.0010
# Epoch 16/300
# 219/219 [==============================] - 7s 31ms/step - loss: 443.1087 - root_mean_squared_error: 21.0501 - val_loss: 482.0493 - val_root_mean_squared_error: 21.9556 - lr: 0.0010
# Epoch 17/300
# 219/219 [==============================] - 5s 21ms/step - loss: 439.3842 - root_mean_squared_error: 20.9615 - val_loss: 484.2402 - val_root_mean_squared_error: 22.0055 - lr: 0.0010
# Epoch 18/300
# 219/219 [==============================] - 6s 28ms/step - loss: 437.2322 - root_mean_squared_error: 20.9101 - val_loss: 481.4717 - val_root_mean_squared_error: 21.9425 - lr: 0.0010
# Epoch 19/300
# 219/219 [==============================] - 6s 28ms/step - loss: 435.8668 - root_mean_squared_error: 20.8774 - val_loss: 480.6575 - val_root_mean_squared_error: 21.9239 - lr: 0.0010
# Epoch 20/300
# 219/219 [==============================] - 6s 27ms/step - loss: 435.0365 - root_mean_squared_error: 20.8575 - val_loss: 480.8219 - val_root_mean_squared_error: 21.9277 - lr: 0.0010
# Epoch 21/300
# 219/219 [==============================] - 6s 30ms/step - loss: 434.2125 - root_mean_squared_error: 20.8378 - val_loss: 474.5024 - val_root_mean_squared_error: 21.7831 - lr: 0.0010
# Epoch 22/300
# 219/219 [==============================] - 4s 19ms/step - loss: 432.3116 - root_mean_squared_error: 20.7921 - val_loss: 476.5827 - val_root_mean_squared_error: 21.8308 - lr: 0.0010
# Epoch 23/300
# 219/219 [==============================] - 6s 25ms/step - loss: 430.8826 - root_mean_squared_error: 20.7577 - val_loss: 477.4616 - val_root_mean_squared_error: 21.8509 - lr: 0.0010
# Epoch 24/300
# 219/219 [==============================] - 7s 31ms/step - loss: 431.1619 - root_mean_squared_error: 20.7644 - val_loss: 474.1078 - val_root_mean_squared_error: 21.7740 - lr: 0.0010
# Epoch 25/300
# 219/219 [==============================] - 4s 20ms/step - loss: 428.6320 - root_mean_squared_error: 20.7034 - val_loss: 474.6716 - val_root_mean_squared_error: 21.7870 - lr: 0.0010
# Epoch 26/300
# 219/219 [==============================] - 5s 24ms/step - loss: 427.4623 - root_mean_squared_error: 20.6752 - val_loss: 476.8856 - val_root_mean_squared_error: 21.8377 - lr: 0.0010
# Epoch 27/300
# 219/219 [==============================] - 6s 28ms/step - loss: 426.3336 - root_mean_squared_error: 20.6478 - val_loss: 473.9858 - val_root_mean_squared_error: 21.7712 - lr: 0.0010
# Epoch 28/300
# 219/219 [==============================] - 6s 27ms/step - loss: 425.0500 - root_mean_squared_error: 20.6167 - val_loss: 476.0141 - val_root_mean_squared_error: 21.8177 - lr: 0.0010
# Epoch 29/300
# 219/219 [==============================] - 6s 29ms/step - loss: 425.7831 - root_mean_squared_error: 20.6345 - val_loss: 473.9016 - val_root_mean_squared_error: 21.7693 - lr: 0.0010
# Epoch 30/300
# 219/219 [==============================] - 5s 24ms/step - loss: 423.0984 - root_mean_squared_error: 20.5694 - val_loss: 474.1254 - val_root_mean_squared_error: 21.7744 - lr: 0.0010
# Epoch 31/300
# 219/219 [==============================] - 4s 19ms/step - loss: 422.2765 - root_mean_squared_error: 20.5494 - val_loss: 474.6817 - val_root_mean_squared_error: 21.7872 - lr: 0.0010
# Epoch 32/300
# 219/219 [==============================] - 6s 27ms/step - loss: 421.8288 - root_mean_squared_error: 20.5385 - val_loss: 479.5615 - val_root_mean_squared_error: 21.8989 - lr: 0.0010
# Epoch 33/300
# 219/219 [==============================] - 4s 19ms/step - loss: 420.5313 - root_mean_squared_error: 20.5069 - val_loss: 474.4951 - val_root_mean_squared_error: 21.7829 - lr: 0.0010
# Epoch 34/300
# 219/219 [==============================] - 8s 36ms/step - loss: 419.6487 - root_mean_squared_error: 20.4853 - val_loss: 472.1036 - val_root_mean_squared_error: 21.7279 - lr: 0.0010
# Epoch 35/300
# 219/219 [==============================] - 4s 19ms/step - loss: 420.1902 - root_mean_squared_error: 20.4985 - val_loss: 473.6488 - val_root_mean_squared_error: 21.7635 - lr: 0.0010
# Epoch 36/300
# 219/219 [==============================] - 6s 26ms/step - loss: 419.9862 - root_mean_squared_error: 20.4936 - val_loss: 473.0584 - val_root_mean_squared_error: 21.7499 - lr: 0.0010
# Epoch 37/300
# 219/219 [==============================] - 7s 32ms/step - loss: 418.1960 - root_mean_squared_error: 20.4498 - val_loss: 471.9082 - val_root_mean_squared_error: 21.7234 - lr: 0.0010
# Epoch 38/300
# 219/219 [==============================] - 7s 34ms/step - loss: 417.0790 - root_mean_squared_error: 20.4225 - val_loss: 467.7381 - val_root_mean_squared_error: 21.6273 - lr: 0.0010
# Epoch 39/300
# 219/219 [==============================] - 6s 26ms/step - loss: 417.6624 - root_mean_squared_error: 20.4368 - val_loss: 470.6877 - val_root_mean_squared_error: 21.6953 - lr: 0.0010
# Epoch 40/300
# 219/219 [==============================] - 4s 19ms/step - loss: 416.8506 - root_mean_squared_error: 20.4169 - val_loss: 468.3237 - val_root_mean_squared_error: 21.6408 - lr: 0.0010
# Epoch 41/300
# 219/219 [==============================] - 5s 21ms/step - loss: 416.5762 - root_mean_squared_error: 20.4102 - val_loss: 472.4226 - val_root_mean_squared_error: 21.7353 - lr: 0.0010
# Epoch 42/300
# 219/219 [==============================] - 5s 22ms/step - loss: 415.6489 - root_mean_squared_error: 20.3875 - val_loss: 469.0681 - val_root_mean_squared_error: 21.6580 - lr: 0.0010
# Epoch 43/300
# 219/219 [==============================] - 4s 19ms/step - loss: 415.1455 - root_mean_squared_error: 20.3751 - val_loss: 471.4969 - val_root_mean_squared_error: 21.7140 - lr: 0.0010
# Epoch 44/300
# 219/219 [==============================] - 6s 26ms/step - loss: 414.4974 - root_mean_squared_error: 20.3592 - val_loss: 471.7054 - val_root_mean_squared_error: 21.7188 - lr: 0.0010
# Epoch 45/300
# 219/219 [==============================] - 4s 19ms/step - loss: 414.7133 - root_mean_squared_error: 20.3645 - val_loss: 472.3302 - val_root_mean_squared_error: 21.7332 - lr: 0.0010
# Epoch 46/300
# 219/219 [==============================] - 4s 20ms/step - loss: 413.0307 - root_mean_squared_error: 20.3232 - val_loss: 473.2274 - val_root_mean_squared_error: 21.7538 - lr: 0.0010
# Epoch 47/300
# 219/219 [==============================] - 6s 27ms/step - loss: 412.3599 - root_mean_squared_error: 20.3066 - val_loss: 468.0847 - val_root_mean_squared_error: 21.6353 - lr: 0.0010
# Epoch 48/300
# 219/219 [==============================] - 4s 19ms/step - loss: 413.6966 - root_mean_squared_error: 20.3395 - val_loss: 469.6905 - val_root_mean_squared_error: 21.6723 - lr: 0.0010
# Epoch 49/300
# 219/219 [==============================] - 5s 22ms/step - loss: 407.2346 - root_mean_squared_error: 20.1801 - val_loss: 468.1601 - val_root_mean_squared_error: 21.6370 - lr: 1.0000e-04
# Epoch 50/300
# 219/219 [==============================] - 6s 29ms/step - loss: 403.7256 - root_mean_squared_error: 20.0929 - val_loss: 466.8170 - val_root_mean_squared_error: 21.6059 - lr: 1.0000e-04
# Epoch 51/300
# 219/219 [==============================] - 8s 37ms/step - loss: 403.3929 - root_mean_squared_error: 20.0846 - val_loss: 465.3406 - val_root_mean_squared_error: 21.5718 - lr: 1.0000e-04
# Epoch 52/300
# 219/219 [==============================] - 5s 21ms/step - loss: 404.1503 - root_mean_squared_error: 20.1035 - val_loss: 466.9225 - val_root_mean_squared_error: 21.6084 - lr: 1.0000e-04
# Epoch 53/300
# 219/219 [==============================] - 5s 24ms/step - loss: 402.8122 - root_mean_squared_error: 20.0702 - val_loss: 466.3309 - val_root_mean_squared_error: 21.5947 - lr: 1.0000e-04
# Epoch 54/300
# 219/219 [==============================] - 5s 24ms/step - loss: 402.0299 - root_mean_squared_error: 20.0507 - val_loss: 466.0654 - val_root_mean_squared_error: 21.5885 - lr: 1.0000e-04
# Epoch 55/300
# 219/219 [==============================] - 4s 19ms/step - loss: 402.0441 - root_mean_squared_error: 20.0510 - val_loss: 466.9770 - val_root_mean_squared_error: 21.6097 - lr: 1.0000e-04
# Epoch 56/300
# 219/219 [==============================] - 6s 26ms/step - loss: 402.1408 - root_mean_squared_error: 20.0534 - val_loss: 466.9813 - val_root_mean_squared_error: 21.6097 - lr: 1.0000e-04
# Epoch 57/300
# 219/219 [==============================] - 4s 19ms/step - loss: 400.7252 - root_mean_squared_error: 20.0181 - val_loss: 466.7900 - val_root_mean_squared_error: 21.6053 - lr: 1.0000e-04
# Epoch 58/300
# 219/219 [==============================] - 6s 26ms/step - loss: 400.0742 - root_mean_squared_error: 20.0019 - val_loss: 465.7607 - val_root_mean_squared_error: 21.5815 - lr: 1.0000e-04
# Epoch 59/300
# 219/219 [==============================] - 4s 18ms/step - loss: 400.8037 - root_mean_squared_error: 20.0201 - val_loss: 466.2924 - val_root_mean_squared_error: 21.5938 - lr: 1.0000e-04
# Epoch 60/300
# 219/219 [==============================] - 5s 21ms/step - loss: 401.1739 - root_mean_squared_error: 20.0293 - val_loss: 465.7943 - val_root_mean_squared_error: 21.5823 - lr: 1.0000e-04
# Epoch 61/300
# 219/219 [==============================] - 5s 22ms/step - loss: 400.4184 - root_mean_squared_error: 20.0105 - val_loss: 465.3750 - val_root_mean_squared_error: 21.5726 - lr: 1.0000e-04
# Epoch 62/300
# 219/219 [==============================] - 6s 28ms/step - loss: 398.7433 - root_mean_squared_error: 19.9686 - val_loss: 463.6679 - val_root_mean_squared_error: 21.5329 - lr: 1.0000e-05
# Epoch 63/300
# 219/219 [==============================] - 6s 29ms/step - loss: 399.2484 - root_mean_squared_error: 19.9812 - val_loss: 463.4741 - val_root_mean_squared_error: 21.5284 - lr: 1.0000e-05
# Epoch 64/300
# 219/219 [==============================] - 7s 31ms/step - loss: 398.8165 - root_mean_squared_error: 19.9704 - val_loss: 463.2909 - val_root_mean_squared_error: 21.5242 - lr: 1.0000e-05
# Epoch 65/300
# 219/219 [==============================] - 8s 37ms/step - loss: 399.1801 - root_mean_squared_error: 19.9795 - val_loss: 463.2341 - val_root_mean_squared_error: 21.5229 - lr: 1.0000e-05
# Epoch 66/300
# 219/219 [==============================] - 7s 31ms/step - loss: 399.2337 - root_mean_squared_error: 19.9808 - val_loss: 463.1257 - val_root_mean_squared_error: 21.5204 - lr: 1.0000e-05
# Epoch 67/300
# 219/219 [==============================] - 6s 28ms/step - loss: 399.1208 - root_mean_squared_error: 19.9780 - val_loss: 463.1257 - val_root_mean_squared_error: 21.5204 - lr: 1.0000e-05
# Epoch 68/300
# 219/219 [==============================] - 6s 26ms/step - loss: 399.4859 - root_mean_squared_error: 19.9871 - val_loss: 463.1971 - val_root_mean_squared_error: 21.5220 - lr: 1.0000e-05
# Epoch 69/300
# 219/219 [==============================] - 6s 28ms/step - loss: 399.1603 - root_mean_squared_error: 19.9790 - val_loss: 462.9941 - val_root_mean_squared_error: 21.5173 - lr: 1.0000e-05
# Epoch 70/300
# 219/219 [==============================] - 7s 33ms/step - loss: 398.0888 - root_mean_squared_error: 19.9522 - val_loss: 462.7964 - val_root_mean_squared_error: 21.5127 - lr: 1.0000e-05
# Epoch 71/300
# 219/219 [==============================] - 6s 27ms/step - loss: 398.9310 - root_mean_squared_error: 19.9733 - val_loss: 463.1242 - val_root_mean_squared_error: 21.5203 - lr: 1.0000e-05
# Epoch 72/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.9951 - root_mean_squared_error: 19.9749 - val_loss: 463.2765 - val_root_mean_squared_error: 21.5239 - lr: 1.0000e-05
# Epoch 73/300
# 219/219 [==============================] - 4s 20ms/step - loss: 398.9011 - root_mean_squared_error: 19.9725 - val_loss: 463.1399 - val_root_mean_squared_error: 21.5207 - lr: 1.0000e-05
# Epoch 74/300
# 219/219 [==============================] - 6s 27ms/step - loss: 397.6670 - root_mean_squared_error: 19.9416 - val_loss: 463.5198 - val_root_mean_squared_error: 21.5295 - lr: 1.0000e-05
# Epoch 75/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.7644 - root_mean_squared_error: 19.9691 - val_loss: 463.4918 - val_root_mean_squared_error: 21.5289 - lr: 1.0000e-05
# Epoch 76/300
# 219/219 [==============================] - 5s 24ms/step - loss: 399.1018 - root_mean_squared_error: 19.9775 - val_loss: 463.2310 - val_root_mean_squared_error: 21.5228 - lr: 1.0000e-05
# Epoch 77/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.0483 - root_mean_squared_error: 19.9511 - val_loss: 462.9555 - val_root_mean_squared_error: 21.5164 - lr: 1.0000e-05
# Epoch 78/300
# 219/219 [==============================] - 6s 27ms/step - loss: 398.8328 - root_mean_squared_error: 19.9708 - val_loss: 463.1533 - val_root_mean_squared_error: 21.5210 - lr: 1.0000e-05
# Epoch 79/300
# 219/219 [==============================] - 4s 19ms/step - loss: 397.9941 - root_mean_squared_error: 19.9498 - val_loss: 463.2480 - val_root_mean_squared_error: 21.5232 - lr: 1.0000e-05
# Epoch 80/300
# 219/219 [==============================] - 4s 19ms/step - loss: 398.9915 - root_mean_squared_error: 19.9748 - val_loss: 463.1393 - val_root_mean_squared_error: 21.5207 - lr: 1.0000e-05
# Epoch 81/300
# 219/219 [==============================] - 6s 27ms/step - loss: 396.9326 - root_mean_squared_error: 19.9232 - val_loss: 463.1490 - val_root_mean_squared_error: 21.5209 - lr: 1.0000e-06
# ...
# 219/219 [==============================] - 4s 20ms/step - loss: 420.6393 - root_mean_squared_error: 20.5095 - val_loss: 474.1347 - val_root_mean_squared_error: 21.7746 - lr: 0.0010
# Epoch 45/300
# 219/219 [==============================] - 5s 22ms/step - loss: 419.8068 - root_mean_squared_error: 20.4892 - val_loss: 473.8885 - val_root_mean_squared_error: 21.7690 - lr: 0.0010
# Epoch 46/300
# 219/219 [==============================] - 6s 26ms/step - loss: 419.5717 - root_mean_squared_error: 20.4834 - val_loss: 472.8427 - val_root_mean_squared_error: 21.7449 - lr: 0.0010
# Epoch 47/300
# 219/219 [==============================] - 4s 20ms/step - loss: 419.3328 - root_mean_squared_error: 20.4776 - val_loss: 469.5931 - val_root_mean_squared_error: 21.6701 - lr: 0.0010
# Epoch 48/300
# 219/219 [==============================] - 6s 29ms/step - loss: 417.3191 - root_mean_squared_error: 20.4284 - val_loss: 474.7054 - val_root_mean_squared_error: 21.7877 - lr: 0.0010
# Epoch 49/300
# 219/219 [==============================] - 5s 21ms/step - loss: 416.0095 - root_mean_squared_error: 20.3963 - val_loss: 471.8103 - val_root_mean_squared_error: 21.7212 - lr: 0.0010
# Epoch 50/300
# 219/219 [==============================] - 5s 21ms/step - loss: 415.5631 - root_mean_squared_error: 20.3854 - val_loss: 470.5820 - val_root_mean_squared_error: 21.6929 - lr: 0.0010
# Epoch 51/300
# 219/219 [==============================] - 6s 29ms/step - loss: 414.7737 - root_mean_squared_error: 20.3660 - val_loss: 473.7673 - val_root_mean_squared_error: 21.7662 - lr: 0.0010
# Epoch 52/300
# 219/219 [==============================] - 7s 30ms/step - loss: 410.7483 - root_mean_squared_error: 20.2669 - val_loss: 465.8623 - val_root_mean_squared_error: 21.5838 - lr: 1.0000e-04
# Epoch 53/300
# 219/219 [==============================] - 6s 29ms/step - loss: 407.5244 - root_mean_squared_error: 20.1872 - val_loss: 465.8879 - val_root_mean_squared_error: 21.5844 - lr: 1.0000e-04
# Epoch 54/300
# 219/219 [==============================] - 5s 21ms/step - loss: 405.8127 - root_mean_squared_error: 20.1448 - val_loss: 465.9111 - val_root_mean_squared_error: 21.5850 - lr: 1.0000e-04
# Epoch 55/300
# 219/219 [==============================] - 6s 29ms/step - loss: 405.0026 - root_mean_squared_error: 20.1247 - val_loss: 466.0709 - val_root_mean_squared_error: 21.5887 - lr: 1.0000e-04
# Epoch 56/300
# 219/219 [==============================] - 7s 30ms/step - loss: 406.7005 - root_mean_squared_error: 20.1668 - val_loss: 465.1330 - val_root_mean_squared_error: 21.5669 - lr: 1.0000e-04
# Epoch 57/300
# 219/219 [==============================] - 5s 22ms/step - loss: 404.4933 - root_mean_squared_error: 20.1120 - val_loss: 465.8660 - val_root_mean_squared_error: 21.5839 - lr: 1.0000e-04
# Epoch 58/300
# 219/219 [==============================] - 5s 21ms/step - loss: 405.9268 - root_mean_squared_error: 20.1476 - val_loss: 465.6176 - val_root_mean_squared_error: 21.5782 - lr: 1.0000e-04
# Epoch 59/300
# 219/219 [==============================] - 8s 38ms/step - loss: 404.4673 - root_mean_squared_error: 20.1114 - val_loss: 464.8009 - val_root_mean_squared_error: 21.5592 - lr: 1.0000e-04
# Epoch 60/300
# 219/219 [==============================] - 5s 21ms/step - loss: 403.0735 - root_mean_squared_error: 20.0767 - val_loss: 465.2542 - val_root_mean_squared_error: 21.5698 - lr: 1.0000e-04
# Epoch 61/300
# 219/219 [==============================] - 6s 29ms/step - loss: 404.6591 - root_mean_squared_error: 20.1161 - val_loss: 465.3325 - val_root_mean_squared_error: 21.5716 - lr: 1.0000e-04
# Epoch 62/300
# 219/219 [==============================] - 4s 20ms/step - loss: 405.3467 - root_mean_squared_error: 20.1332 - val_loss: 465.2262 - val_root_mean_squared_error: 21.5691 - lr: 1.0000e-04
# Epoch 63/300
# 219/219 [==============================] - 8s 38ms/step - loss: 404.8947 - root_mean_squared_error: 20.1220 - val_loss: 464.7639 - val_root_mean_squared_error: 21.5584 - lr: 1.0000e-04
# Epoch 64/300
# 219/219 [==============================] - 7s 30ms/step - loss: 404.0194 - root_mean_squared_error: 20.1002 - val_loss: 464.6545 - val_root_mean_squared_error: 21.5558 - lr: 1.0000e-04
# Epoch 65/300
# 219/219 [==============================] - 8s 39ms/step - loss: 405.5534 - root_mean_squared_error: 20.1384 - val_loss: 464.5110 - val_root_mean_squared_error: 21.5525 - lr: 1.0000e-04
# Epoch 66/300
# 219/219 [==============================] - 5s 21ms/step - loss: 403.7758 - root_mean_squared_error: 20.0942 - val_loss: 465.1383 - val_root_mean_squared_error: 21.5671 - lr: 1.0000e-04
# Epoch 67/300
# 219/219 [==============================] - 6s 29ms/step - loss: 404.2286 - root_mean_squared_error: 20.1054 - val_loss: 465.5499 - val_root_mean_squared_error: 21.5766 - lr: 1.0000e-04
# Epoch 68/300
# 219/219 [==============================] - 5s 21ms/step - loss: 404.2378 - root_mean_squared_error: 20.1057 - val_loss: 465.3978 - val_root_mean_squared_error: 21.5731 - lr: 1.0000e-04
# Epoch 69/300
# 219/219 [==============================] - 8s 35ms/step - loss: 404.4206 - root_mean_squared_error: 20.1102 - val_loss: 464.3220 - val_root_mean_squared_error: 21.5481 - lr: 1.0000e-04
# Epoch 70/300
# 219/219 [==============================] - 4s 20ms/step - loss: 403.8556 - root_mean_squared_error: 20.0962 - val_loss: 464.6759 - val_root_mean_squared_error: 21.5563 - lr: 1.0000e-04
# Epoch 71/300
# 219/219 [==============================] - 4s 20ms/step - loss: 404.0852 - root_mean_squared_error: 20.1019 - val_loss: 464.9237 - val_root_mean_squared_error: 21.5621 - lr: 1.0000e-04
# Epoch 72/300
# 219/219 [==============================] - 8s 39ms/step - loss: 403.2330 - root_mean_squared_error: 20.0807 - val_loss: 464.2662 - val_root_mean_squared_error: 21.5468 - lr: 1.0000e-04
# Epoch 73/300
# 219/219 [==============================] - 5s 21ms/step - loss: 403.7352 - root_mean_squared_error: 20.0932 - val_loss: 464.5041 - val_root_mean_squared_error: 21.5524 - lr: 1.0000e-04
# Epoch 74/300
# 219/219 [==============================] - 6s 26ms/step - loss: 402.0970 - root_mean_squared_error: 20.0524 - val_loss: 465.2719 - val_root_mean_squared_error: 21.5702 - lr: 1.0000e-04
# Epoch 75/300
# 219/219 [==============================] - 4s 20ms/step - loss: 403.2332 - root_mean_squared_error: 20.0807 - val_loss: 464.7641 - val_root_mean_squared_error: 21.5584 - lr: 1.0000e-04
# Epoch 76/300
# 219/219 [==============================] - 5s 25ms/step - loss: 403.2168 - root_mean_squared_error: 20.0803 - val_loss: 464.8053 - val_root_mean_squared_error: 21.5593 - lr: 1.0000e-04
# Epoch 77/300
# 219/219 [==============================] - 4s 20ms/step - loss: 403.3654 - root_mean_squared_error: 20.0840 - val_loss: 465.4496 - val_root_mean_squared_error: 21.5743 - lr: 1.0000e-04
# Epoch 78/300
# 219/219 [==============================] - 6s 28ms/step - loss: 403.6505 - root_mean_squared_error: 20.0911 - val_loss: 466.1628 - val_root_mean_squared_error: 21.5908 - lr: 1.0000e-04
# Epoch 79/300
# 219/219 [==============================] - 5s 21ms/step - loss: 403.5600 - root_mean_squared_error: 20.0888 - val_loss: 464.8493 - val_root_mean_squared_error: 21.5604 - lr: 1.0000e-04
# Epoch 80/300
# 219/219 [==============================] - 6s 28ms/step - loss: 403.5530 - root_mean_squared_error: 20.0886 - val_loss: 464.7390 - val_root_mean_squared_error: 21.5578 - lr: 1.0000e-04
# Epoch 81/300
# 219/219 [==============================] - 4s 20ms/step - loss: 402.5139 - root_mean_squared_error: 20.0627 - val_loss: 464.6742 - val_root_mean_squared_error: 21.5563 - lr: 1.0000e-04
# Epoch 82/300
# 219/219 [==============================] - 6s 28ms/step - loss: 401.7758 - root_mean_squared_error: 20.0443 - val_loss: 464.8723 - val_root_mean_squared_error: 21.5609 - lr: 1.0000e-04
# Epoch 83/300
# 219/219 [==============================] - 6s 30ms/step - loss: 401.9406 - root_mean_squared_error: 20.0485 - val_loss: 463.6661 - val_root_mean_squared_error: 21.5329 - lr: 1.0000e-05
# Epoch 84/300
# 219/219 [==============================] - 9s 42ms/step - loss: 400.7547 - root_mean_squared_error: 20.0189 - val_loss: 463.6593 - val_root_mean_squared_error: 21.5327 - lr: 1.0000e-05
# Epoch 85/300
# 219/219 [==============================] - 7s 31ms/step - loss: 402.2545 - root_mean_squared_error: 20.0563 - val_loss: 463.5916 - val_root_mean_squared_error: 21.5312 - lr: 1.0000e-05
# Epoch 86/300
# 219/219 [==============================] - 6s 26ms/step - loss: 401.0077 - root_mean_squared_error: 20.0252 - val_loss: 463.6408 - val_root_mean_squared_error: 21.5323 - lr: 1.0000e-05
# Epoch 87/300
# 219/219 [==============================] - 6s 25ms/step - loss: 400.0132 - root_mean_squared_error: 20.0003 - val_loss: 463.6313 - val_root_mean_squared_error: 21.5321 - lr: 1.0000e-05
# Epoch 88/300
# 219/219 [==============================] - 7s 31ms/step - loss: 402.0316 - root_mean_squared_error: 20.0507 - val_loss: 463.3696 - val_root_mean_squared_error: 21.5260 - lr: 1.0000e-05
# Epoch 89/300
# 219/219 [==============================] - 4s 20ms/step - loss: 401.0156 - root_mean_squared_error: 20.0254 - val_loss: 463.7095 - val_root_mean_squared_error: 21.5339 - lr: 1.0000e-05
# Epoch 90/300
# 219/219 [==============================] - 5s 23ms/step - loss: 400.1450 - root_mean_squared_error: 20.0036 - val_loss: 463.6368 - val_root_mean_squared_error: 21.5322 - lr: 1.0000e-05
# Epoch 91/300
# 219/219 [==============================] - 6s 26ms/step - loss: 401.2161 - root_mean_squared_error: 20.0304 - val_loss: 463.5330 - val_root_mean_squared_error: 21.5298 - lr: 1.0000e-05
# Epoch 92/300
# 219/219 [==============================] - 6s 26ms/step - loss: 401.4263 - root_mean_squared_error: 20.0356 - val_loss: 463.6292 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-05
# Epoch 93/300
# 219/219 [==============================] - 5s 22ms/step - loss: 401.6198 - root_mean_squared_error: 20.0405 - val_loss: 463.6155 - val_root_mean_squared_error: 21.5317 - lr: 1.0000e-05
# Epoch 94/300
# 219/219 [==============================] - 5s 21ms/step - loss: 400.5114 - root_mean_squared_error: 20.0128 - val_loss: 463.6806 - val_root_mean_squared_error: 21.5332 - lr: 1.0000e-05
# Epoch 95/300
# 219/219 [==============================] - 6s 29ms/step - loss: 400.3615 - root_mean_squared_error: 20.0090 - val_loss: 463.6137 - val_root_mean_squared_error: 21.5317 - lr: 1.0000e-05
# Epoch 96/300
# 219/219 [==============================] - 4s 20ms/step - loss: 401.2848 - root_mean_squared_error: 20.0321 - val_loss: 463.5196 - val_root_mean_squared_error: 21.5295 - lr: 1.0000e-05
# Epoch 97/300
# 219/219 [==============================] - 6s 29ms/step - loss: 400.1845 - root_mean_squared_error: 20.0046 - val_loss: 463.5422 - val_root_mean_squared_error: 21.5300 - lr: 1.0000e-05
# Epoch 98/300
# 219/219 [==============================] - 5s 21ms/step - loss: 399.7421 - root_mean_squared_error: 19.9936 - val_loss: 463.5752 - val_root_mean_squared_error: 21.5308 - lr: 1.0000e-05
# Epoch 99/300
# 219/219 [==============================] - 5s 22ms/step - loss: 401.7083 - root_mean_squared_error: 20.0427 - val_loss: 463.5827 - val_root_mean_squared_error: 21.5310 - lr: 1.0000e-06
# Epoch 100/300
# 219/219 [==============================] - 6s 27ms/step - loss: 399.7555 - root_mean_squared_error: 19.9939 - val_loss: 463.6273 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-06
# Epoch 101/300
# 219/219 [==============================] - 5s 25ms/step - loss: 400.4951 - root_mean_squared_error: 20.0124 - val_loss: 463.6364 - val_root_mean_squared_error: 21.5322 - lr: 1.0000e-06
# Epoch 102/300
# 219/219 [==============================] - 5s 24ms/step - loss: 400.7598 - root_mean_squared_error: 20.0190 - val_loss: 463.6649 - val_root_mean_squared_error: 21.5329 - lr: 1.0000e-06
# Epoch 103/300
# 219/219 [==============================] - 6s 29ms/step - loss: 401.1288 - root_mean_squared_error: 20.0282 - val_loss: 463.6784 - val_root_mean_squared_error: 21.5332 - lr: 1.0000e-06
# Epoch 104/300
# 219/219 [==============================] - 5s 21ms/step - loss: 400.5775 - root_mean_squared_error: 20.0144 - val_loss: 463.6658 - val_root_mean_squared_error: 21.5329 - lr: 1.0000e-06
# Epoch 105/300
# 219/219 [==============================] - 5s 21ms/step - loss: 401.5626 - root_mean_squared_error: 20.0390 - val_loss: 463.5910 - val_root_mean_squared_error: 21.5312 - lr: 1.0000e-06
# Epoch 106/300
# 219/219 [==============================] - 6s 29ms/step - loss: 400.3719 - root_mean_squared_error: 20.0093 - val_loss: 463.5915 - val_root_mean_squared_error: 21.5312 - lr: 1.0000e-06
# Epoch 107/300
# 219/219 [==============================] - 5s 21ms/step - loss: 402.0790 - root_mean_squared_error: 20.0519 - val_loss: 463.5945 - val_root_mean_squared_error: 21.5312 - lr: 1.0000e-06
# Epoch 108/300
# 219/219 [==============================] - 6s 25ms/step - loss: 400.6935 - root_mean_squared_error: 20.0173 - val_loss: 463.6156 - val_root_mean_squared_error: 21.5317 - lr: 1.0000e-06
# Epoch 109/300
# 219/219 [==============================] - 5s 23ms/step - loss: 399.6010 - root_mean_squared_error: 19.9900 - val_loss: 463.6190 - val_root_mean_squared_error: 21.5318 - lr: 1.0000e-07
# Epoch 110/300
# 219/219 [==============================] - 6s 29ms/step - loss: 401.2336 - root_mean_squared_error: 20.0308 - val_loss: 463.6202 - val_root_mean_squared_error: 21.5318 - lr: 1.0000e-07
# Epoch 111/300
# 219/219 [==============================] - 5s 21ms/step - loss: 400.2629 - root_mean_squared_error: 20.0066 - val_loss: 463.6174 - val_root_mean_squared_error: 21.5318 - lr: 1.0000e-07
# Epoch 112/300
# 219/219 [==============================] - 5s 23ms/step - loss: 401.0665 - root_mean_squared_error: 20.0266 - val_loss: 463.6210 - val_root_mean_squared_error: 21.5319 - lr: 1.0000e-07
# Epoch 113/300
# 219/219 [==============================] - 6s 26ms/step - loss: 398.6782 - root_mean_squared_error: 19.9669 - val_loss: 463.6204 - val_root_mean_squared_error: 21.5318 - lr: 1.0000e-07
# Epoch 114/300
# 219/219 [==============================] - 5s 22ms/step - loss: 401.2749 - root_mean_squared_error: 20.0318 - val_loss: 463.6238 - val_root_mean_squared_error: 21.5319 - lr: 1.0000e-07
# Epoch 115/300
# 219/219 [==============================] - 6s 28ms/step - loss: 401.1768 - root_mean_squared_error: 20.0294 - val_loss: 463.6258 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-07
# Epoch 116/300
# 219/219 [==============================] - 5s 21ms/step - loss: 399.9443 - root_mean_squared_error: 19.9986 - val_loss: 463.6227 - val_root_mean_squared_error: 21.5319 - lr: 1.0000e-07
# Epoch 117/300
# 219/219 [==============================] - 6s 29ms/step - loss: 401.7326 - root_mean_squared_error: 20.0433 - val_loss: 463.6190 - val_root_mean_squared_error: 21.5318 - lr: 1.0000e-07
# Epoch 118/300
# 219/219 [==============================] - 5s 21ms/step - loss: 399.8678 - root_mean_squared_error: 19.9967 - val_loss: 463.6253 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-07
# Epoch 119/300
# 219/219 [==============================] - 5s 22ms/step - loss: 401.3828 - root_mean_squared_error: 20.0345 - val_loss: 463.6252 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-08
# Epoch 120/300
# 219/219 [==============================] - 6s 26ms/step - loss: 399.1172 - root_mean_squared_error: 19.9779 - val_loss: 463.6251 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-08
# Epoch 121/300
# 219/219 [==============================] - 6s 26ms/step - loss: 400.4589 - root_mean_squared_error: 20.0115 - val_loss: 463.6252 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-08
# Epoch 122/300
# 219/219 [==============================] - 5s 23ms/step - loss: 402.2792 - root_mean_squared_error: 20.0569 - val_loss: 463.6258 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-08
# Epoch 123/300
# 219/219 [==============================] - 5s 21ms/step - loss: 401.1266 - root_mean_squared_error: 20.0281 - val_loss: 463.6259 - val_root_mean_squared_error: 21.5320 - lr: 1.0000e-08
# Evaluating on patient_id: 559
# Evaluating on patient_id: 563
# Evaluating on patient_id: 570
# Evaluating on patient_id: 575
# Evaluating on patient_id: 588
# Evaluating on patient_id: 591

# %%
test_errs
# Out:
# [('lmu_2018_ph30min_0', '563', 17.447338104248047),
#  ('lmu_2018_ph30min_0', '570', 15.271833419799805),
#  ('lmu_2018_ph30min_0', '575', 21.337308883666992),
#  ('lmu_2018_ph30min_0', '591', 20.4708309173584),
#  ('lmu_2018_ph30min_0', '588', 16.80900764465332),
#  ('lmu_2018_ph30min_0', '559', 17.684860229492188),
#  ('lmu_2018_ph30min_1', '559', 17.592687606811523),
#  ('lmu_2018_ph30min_1', '563', 17.57193374633789),
#  ('lmu_2018_ph30min_1', '570', 15.185574531555176),
#  ('lmu_2018_ph30min_1', '575', 21.26397705078125),
#  ('lmu_2018_ph30min_1', '588', 16.853023529052734),
#  ('lmu_2018_ph30min_1', '591', 20.570119857788086),
#  ('lmu_2018_ph30min_2', '559', 17.640737533569336),
#  ('lmu_2018_ph30min_2', '563', 17.555335998535156),
#  ('lmu_2018_ph30min_2', '570', 15.322915077209473),
#  ('lmu_2018_ph30min_2', '575', 21.235685348510742),
#  ('lmu_2018_ph30min_2', '588', 16.873811721801758),
#  ('lmu_2018_ph30min_2', '591', 20.500211715698242),
#  ('lmu_2018_ph30min_3', '559', 17.599246978759766),
#  ('lmu_2018_ph30min_3', '563', 17.587570190429688),
#  ('lmu_2018_ph30min_3', '570', 15.209285736083984),
#  ('lmu_2018_ph30min_3', '575', 21.353126525878906),
#  ('lmu_2018_ph30min_3', '588', 16.754716873168945),
#  ('lmu_2018_ph30min_3', '591', 20.52882194519043),
#  ('lmu_2018_ph30min_4', '559', 17.62942123413086),
#  ('lmu_2018_ph30min_4', '563', 17.540117263793945),
#  ('lmu_2018_ph30min_4', '570', 15.174907684326172),
#  ('lmu_2018_ph30min_4', '575', 21.19520378112793),
#  ('lmu_2018_ph30min_4', '588', 16.845420837402344),
#  ('lmu_2018_ph30min_4', '591', 20.47476577758789)]

# %%
val_errs
# Out:
# [('lmu_2018_ph30min_0', '559', 20.631990432739258),
#  ('lmu_2018_ph30min_0', '563', 18.303466796875),
#  ('lmu_2018_ph30min_0', '570', 16.965848922729492),
#  ('lmu_2018_ph30min_0', '575', 20.807308197021484),
#  ('lmu_2018_ph30min_0', '588', 18.931468963623047),
#  ('lmu_2018_ph30min_0', '591', 30.035261154174805),
#  ('lmu_2018_ph30min_1', '559', 20.641620635986328),
#  ('lmu_2018_ph30min_1', '563', 18.385026931762695),
#  ('lmu_2018_ph30min_1', '570', 16.614063262939453),
#  ('lmu_2018_ph30min_1', '575', 20.9461727142334),
#  ('lmu_2018_ph30min_1', '588', 19.264863967895508),
#  ('lmu_2018_ph30min_1', '591', 30.15157699584961),
#  ('lmu_2018_ph30min_2', '559', 20.721525192260742),
#  ('lmu_2018_ph30min_2', '563', 18.306819915771484),
#  ('lmu_2018_ph30min_2', '570', 17.040767669677734),
#  ('lmu_2018_ph30min_2', '575', 20.794530868530273),
#  ('lmu_2018_ph30min_2', '588', 18.897396087646484),
#  ('lmu_2018_ph30min_2', '591', 30.134490966796875),
#  ('lmu_2018_ph30min_3', '559', 20.527406692504883),
#  ('lmu_2018_ph30min_3', '563', 18.34991455078125),
#  ('lmu_2018_ph30min_3', '570', 16.563282012939453),
#  ('lmu_2018_ph30min_3', '575', 20.77094268798828),
#  ('lmu_2018_ph30min_3', '588', 18.860811233520508),
#  ('lmu_2018_ph30min_3', '591', 30.042747497558594),
#  ('lmu_2018_ph30min_4', '559', 20.724201202392578),
#  ('lmu_2018_ph30min_4', '563', 18.413427352905273),
#  ('lmu_2018_ph30min_4', '570', 16.865665435791016),
#  ('lmu_2018_ph30min_4', '575', 20.918046951293945),
#  ('lmu_2018_ph30min_4', '588', 19.16401481628418),
#  ('lmu_2018_ph30min_4', '591', 29.951171875)]

# %%
df_results_test = pd.DataFrame(test_errs, columns=['Model iteration', 'Patient ID', 'RMSE'])
df_results_test['Model'] = df_results_test['Model iteration'].str.replace(r'_\d+$', '', regex=True)

# %%
df_results_test.groupby(['Model iteration'])['RMSE'].agg(['mean'])
# Out:
#                          mean
# Model iteration
# lmu_2018_ph30min_0  18.170197
# lmu_2018_ph30min_1  18.172886
# lmu_2018_ph30min_2  18.188116
# lmu_2018_ph30min_3  18.172128
# lmu_2018_ph30min_4  18.143306

# %%
df_results_test.groupby(['Model iteration', 'Model'])['RMSE'].agg(['mean']).groupby("Model").agg(["mean", "std"])
# Out:
#                        mean
#                        mean       std
# Model
# lmu_2018_ph30min  18.169327  0.016213

# %%
df_results_test.groupby(['Patient ID'])['RMSE'].agg(["mean", "std"])
# Out:
#                  mean       std
# Patient ID
# 559         17.629391  0.036951
# 563         17.540459  0.055007
# 570         15.232903  0.062807
# 575         21.277060  0.067081
# 588         16.827196  0.046787
# 591         20.508950  0.041336
