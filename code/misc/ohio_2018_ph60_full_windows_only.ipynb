# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This notebook uses only full input windows for training, validation and testing on the 2018 editions of OhioT1DM dataset (no interpolation is applied when creating the input-target pairs)

# %% [markdown]
# ## Imports, top level definitions and data loading

# %%
import keras_lmu
import pandas as pd
import os
import tensorflow as tf

from core.pre_processing import build_ohio_dataset, build_windows, get_patient_window
from core.utils import compile_and_fit, plot_loss

# %%
SAMPL_FREQ = 5

PATIENTS_2018 = ["559", "563", "570", "575", "588", "591"]
PATIENTS_2020 = ["540", "544", "552", "567", "584", "596"]

model_name = "lmu_2018_ph60min_full_wins"

# %%
# Load dataset
dataset_2018 = build_ohio_dataset("2018")
# Out:
# Using time to peak: 100 for patient 559
# Identified 35 gaps for train set of 559
# Identified 7 gaps for val set of 559
# Identified 11 gaps for test set of 559
# Using time to peak: 100 for patient 563
# Identified 15 gaps for train set of 563
# Identified 6 gaps for val set of 563
# Identified 3 gaps for test set of 563
# Using time to peak: 100 for patient 570
# Identified 15 gaps for train set of 570
# Identified 5 gaps for val set of 570
# Identified 9 gaps for test set of 570
# Using time to peak: 100 for patient 575
# Identified 56 gaps for train set of 575
# Identified 16 gaps for val set of 575
# Identified 10 gaps for test set of 575
# Using time to peak: 100 for patient 588
# Identified 9 gaps for train set of 588
# Identified 1 gaps for val set of 588
# Identified 2 gaps for test set of 588
# Using time to peak: 100 for patient 591
# Identified 23 gaps for train set of 591
# Identified 3 gaps for val set of 591
# Identified 4 gaps for test set of 591

# %% [markdown]
# ## Setup params for the model and input

# %%
# Path where to store the trained models
root_path = "models"

# 12 steps -> 60 minutes prediction horizon
PH = 12
batch_size = 256

# 30 minutes of input
input_len = 30

features = ["Time", "Glucose", "Rapid Insulin sub_tissue", "Carbohydrates gut", "finger_stick"]

# %% [markdown]
# ## Create pre-processed input-target pairs for the model
# Additionally create input-target pairs per each patient so that we can evaluate the performance individually per patient

# %%
w_2018, _ = build_windows(dataset_2018, features, input_len // SAMPL_FREQ, 1, PH, drop_noisy=False, batch_size=batch_size, min_max_scale=False, interpolate=False)

# %%
patient_windows_2018 = {}
for p_tr_df, p_v_df, p_tst_df, patient_id in dataset_2018:
    patient_windows_2018[patient_id] = get_patient_window(
        (p_tr_df, p_v_df, p_tst_df),
        features,
        input_len // SAMPL_FREQ,
        1,
        PH,
        drop_noisy=False,
        batch_size=batch_size,
        min_max_scale=False,
        interpolate=False,
    )

# %% [markdown]
# ## Train and evaluate models

# %%
def train_model(patient_windows, model_name: str, train_window):
    lmu_layer = keras_lmu.LMU(
        memory_d=4,
        order=54,
        theta=input_len // SAMPL_FREQ,
        hidden_to_memory=False,
        memory_to_memory=True,
        input_to_hidden=False,
        hidden_cell=tf.keras.layers.LSTMCell(units=144),
        return_sequences=False,
        dropout=0.1,
        recurrent_dropout=0,
    )
    inputs = tf.keras.Input((input_len // SAMPL_FREQ, 4))
    lmus = lmu_layer(inputs)
    outputs = tf.keras.layers.Dense(1)(lmus)
    output_plus_input = tf.keras.layers.Add()([outputs, inputs[:, -1, 0]])

    model = tf.keras.Model(inputs=inputs, outputs=output_plus_input)
    print(model.summary())

    history = compile_and_fit(model, train_window, max_epochs=300, learning_rate=10**-3, patience=35, store_model=model_name)
    plot_loss(history, "Loss", False)

    best_model = tf.keras.models.load_model(os.path.join(root_path, model_name))

    results_val = []
    results_test = []

    for patient_id, patient_w in patient_windows.items():
        print("Evaluating on patient_id:", patient_id)
        val_p = best_model.evaluate(patient_w.val, verbose=0)[1]
        test_p = best_model.evaluate(patient_w.test, verbose=0)[1]
        results_val.append((model_name, patient_id, val_p))
        results_test.append((model_name, patient_id, test_p))
    return results_val, results_test

# %%
val_errs, test_errs = train_model(patient_windows_2018, f"{model_name}_0", w_2018)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 6, 4)]               0         []
#
#  lmu (LMU)                   (None, 144)                  208816    ['input_1[0][0]']
#
#  dense (Dense)               (None, 1)                    145       ['lmu[0][0]']
#
#  tf.__operators__.getitem (  (None,)                      0         ['input_1[0][0]']
#  SlicingOpLambda)
#
#  add (Add)                   (None, 1)                    0         ['dense[0][0]',
#                                                                      'tf.__operators__.getitem[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 208961 (816.25 KB)
# Trainable params: 208961 (816.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# all rolling: 9676
# 8458 size before reduction
# 8458 size after reduction
# 414 windows with too many nans
# 787 windows with empty labels
# all rolling: 10505
# 9705 size before reduction
# 9705 size after reduction
# 273 windows with too many nans
# 510 windows with empty labels
# all rolling: 9446
# 8725 size before reduction
# 8725 size after reduction
# 215 windows with too many nans
# 489 windows with empty labels
# all rolling: 10483
# 9568 size before reduction
# 9568 size after reduction
# 251 windows with too many nans
# 647 windows with empty labels
# all rolling: 10598
# 9985 size before reduction
# 9985 size after reduction
# 226 windows with too many nans
# 370 windows with empty labels
# all rolling: 10368
# 8351 size before reduction
# 8351 size after reduction
# 487 windows with too many nans
# 1513 windows with empty labels
# all rolling: 2420
# 2208 size before reduction
# 2208 size after reduction
# 75 windows with too many nans
# 120 windows with empty labels
# all rolling: 2627
# 2431 size before reduction
# 2431 size after reduction
# 77 windows with too many nans
# 102 windows with empty labels
# all rolling: 2362
# 2133 size before reduction
# 2133 size after reduction
# 79 windows with too many nans
# 133 windows with empty labels
# all rolling: 2621
# 2355 size before reduction
# 2355 size after reduction
# 94 windows with too many nans
# 155 windows with empty labels
# all rolling: 2650
# 2600 size before reduction
# 2600 size after reduction
# 18 windows with too many nans
# 15 windows with empty labels
# all rolling: 2592
# 2493 size before reduction
# 2493 size after reduction
# 31 windows with too many nans
# 51 windows with empty labels
# Epoch 1/300
# 215/215 [==============================] - 11s 35ms/step - loss: 1487.3405 - root_mean_squared_error: 38.5661 - val_loss: 1517.1575 - val_root_mean_squared_error: 38.9507 - lr: 0.0010
# Epoch 2/300
# 215/215 [==============================] - 7s 30ms/step - loss: 1353.5621 - root_mean_squared_error: 36.7908 - val_loss: 1413.2406 - val_root_mean_squared_error: 37.5931 - lr: 0.0010
# Epoch 3/300
# 215/215 [==============================] - 7s 34ms/step - loss: 1297.7600 - root_mean_squared_error: 36.0244 - val_loss: 1401.6207 - val_root_mean_squared_error: 37.4382 - lr: 0.0010
# Epoch 4/300
# 215/215 [==============================] - 6s 29ms/step - loss: 1268.9167 - root_mean_squared_error: 35.6219 - val_loss: 1352.9287 - val_root_mean_squared_error: 36.7822 - lr: 0.0010
# Epoch 5/300
# 215/215 [==============================] - 6s 29ms/step - loss: 1246.4156 - root_mean_squared_error: 35.3046 - val_loss: 1335.1038 - val_root_mean_squared_error: 36.5391 - lr: 0.0010
# Epoch 6/300
# 215/215 [==============================] - 8s 38ms/step - loss: 1234.3947 - root_mean_squared_error: 35.1340 - val_loss: 1314.4946 - val_root_mean_squared_error: 36.2560 - lr: 0.0010
# Epoch 7/300
# 215/215 [==============================] - 7s 31ms/step - loss: 1215.2668 - root_mean_squared_error: 34.8607 - val_loss: 1305.7882 - val_root_mean_squared_error: 36.1357 - lr: 0.0010
# Epoch 8/300
# 215/215 [==============================] - 4s 18ms/step - loss: 1210.3026 - root_mean_squared_error: 34.7894 - val_loss: 1307.9657 - val_root_mean_squared_error: 36.1658 - lr: 0.0010
# Epoch 9/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1198.3501 - root_mean_squared_error: 34.6172 - val_loss: 1302.6136 - val_root_mean_squared_error: 36.0917 - lr: 0.0010
# Epoch 10/300
# 215/215 [==============================] - 6s 29ms/step - loss: 1193.4871 - root_mean_squared_error: 34.5469 - val_loss: 1294.9562 - val_root_mean_squared_error: 35.9855 - lr: 0.0010
# Epoch 11/300
# 215/215 [==============================] - 8s 35ms/step - loss: 1183.2373 - root_mean_squared_error: 34.3982 - val_loss: 1281.8014 - val_root_mean_squared_error: 35.8023 - lr: 0.0010
# Epoch 12/300
# 215/215 [==============================] - 8s 36ms/step - loss: 1175.0061 - root_mean_squared_error: 34.2784 - val_loss: 1264.9392 - val_root_mean_squared_error: 35.5660 - lr: 0.0010
# Epoch 13/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1168.2925 - root_mean_squared_error: 34.1803 - val_loss: 1291.3667 - val_root_mean_squared_error: 35.9356 - lr: 0.0010
# Epoch 14/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1166.9656 - root_mean_squared_error: 34.1609 - val_loss: 1255.5140 - val_root_mean_squared_error: 35.4332 - lr: 0.0010
# Epoch 15/300
# 215/215 [==============================] - 6s 29ms/step - loss: 1160.6405 - root_mean_squared_error: 34.0682 - val_loss: 1250.6218 - val_root_mean_squared_error: 35.3641 - lr: 0.0010
# Epoch 16/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1152.3569 - root_mean_squared_error: 33.9464 - val_loss: 1235.8340 - val_root_mean_squared_error: 35.1544 - lr: 0.0010
# Epoch 17/300
# 215/215 [==============================] - 8s 39ms/step - loss: 1147.1760 - root_mean_squared_error: 33.8700 - val_loss: 1233.5463 - val_root_mean_squared_error: 35.1219 - lr: 0.0010
# Epoch 18/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1146.4025 - root_mean_squared_error: 33.8586 - val_loss: 1246.6021 - val_root_mean_squared_error: 35.3073 - lr: 0.0010
# Epoch 19/300
# 215/215 [==============================] - 5s 24ms/step - loss: 1137.4860 - root_mean_squared_error: 33.7266 - val_loss: 1241.4613 - val_root_mean_squared_error: 35.2344 - lr: 0.0010
# Epoch 20/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1135.8082 - root_mean_squared_error: 33.7018 - val_loss: 1244.1075 - val_root_mean_squared_error: 35.2719 - lr: 0.0010
# Epoch 21/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1131.4922 - root_mean_squared_error: 33.6377 - val_loss: 1248.5981 - val_root_mean_squared_error: 35.3355 - lr: 0.0010
# Epoch 22/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1126.0442 - root_mean_squared_error: 33.5566 - val_loss: 1300.8107 - val_root_mean_squared_error: 36.0668 - lr: 0.0010
# Epoch 23/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1126.6952 - root_mean_squared_error: 33.5663 - val_loss: 1230.2594 - val_root_mean_squared_error: 35.0751 - lr: 0.0010
# Epoch 24/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1125.9863 - root_mean_squared_error: 33.5557 - val_loss: 1231.4773 - val_root_mean_squared_error: 35.0924 - lr: 0.0010
# Epoch 25/300
# 215/215 [==============================] - 8s 37ms/step - loss: 1122.6780 - root_mean_squared_error: 33.5064 - val_loss: 1223.1910 - val_root_mean_squared_error: 34.9741 - lr: 0.0010
# Epoch 26/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1114.6652 - root_mean_squared_error: 33.3866 - val_loss: 1249.7577 - val_root_mean_squared_error: 35.3519 - lr: 0.0010
# Epoch 27/300
# 215/215 [==============================] - 6s 26ms/step - loss: 1115.9863 - root_mean_squared_error: 33.4064 - val_loss: 1238.4142 - val_root_mean_squared_error: 35.1911 - lr: 0.0010
# Epoch 28/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1112.9786 - root_mean_squared_error: 33.3613 - val_loss: 1238.5089 - val_root_mean_squared_error: 35.1925 - lr: 0.0010
# Epoch 29/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1104.2289 - root_mean_squared_error: 33.2299 - val_loss: 1236.3550 - val_root_mean_squared_error: 35.1618 - lr: 0.0010
# Epoch 30/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1103.5865 - root_mean_squared_error: 33.2203 - val_loss: 1258.3358 - val_root_mean_squared_error: 35.4730 - lr: 0.0010
# Epoch 31/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1105.8165 - root_mean_squared_error: 33.2538 - val_loss: 1246.8754 - val_root_mean_squared_error: 35.3111 - lr: 0.0010
# Epoch 32/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1102.6805 - root_mean_squared_error: 33.2066 - val_loss: 1228.8063 - val_root_mean_squared_error: 35.0543 - lr: 0.0010
# Epoch 33/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1094.0219 - root_mean_squared_error: 33.0760 - val_loss: 1234.4331 - val_root_mean_squared_error: 35.1345 - lr: 0.0010
# Epoch 34/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1101.4884 - root_mean_squared_error: 33.1887 - val_loss: 1259.9905 - val_root_mean_squared_error: 35.4963 - lr: 0.0010
# Epoch 35/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1096.3915 - root_mean_squared_error: 33.1118 - val_loss: 1251.1136 - val_root_mean_squared_error: 35.3711 - lr: 0.0010
# Epoch 36/300
# 215/215 [==============================] - 7s 31ms/step - loss: 1081.8936 - root_mean_squared_error: 32.8922 - val_loss: 1206.4319 - val_root_mean_squared_error: 34.7337 - lr: 1.0000e-04
# Epoch 37/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1074.1923 - root_mean_squared_error: 32.7749 - val_loss: 1207.5803 - val_root_mean_squared_error: 34.7503 - lr: 1.0000e-04
# Epoch 38/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1073.0995 - root_mean_squared_error: 32.7582 - val_loss: 1210.9454 - val_root_mean_squared_error: 34.7986 - lr: 1.0000e-04
# Epoch 39/300
# 215/215 [==============================] - 8s 36ms/step - loss: 1072.2223 - root_mean_squared_error: 32.7448 - val_loss: 1206.3453 - val_root_mean_squared_error: 34.7325 - lr: 1.0000e-04
# Epoch 40/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1072.3892 - root_mean_squared_error: 32.7474 - val_loss: 1215.4281 - val_root_mean_squared_error: 34.8630 - lr: 1.0000e-04
# Epoch 41/300
# 215/215 [==============================] - 5s 21ms/step - loss: 1068.6819 - root_mean_squared_error: 32.6907 - val_loss: 1208.8839 - val_root_mean_squared_error: 34.7690 - lr: 1.0000e-04
# Epoch 42/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1068.2335 - root_mean_squared_error: 32.6838 - val_loss: 1207.5671 - val_root_mean_squared_error: 34.7501 - lr: 1.0000e-04
# Epoch 43/300
# 215/215 [==============================] - 8s 39ms/step - loss: 1067.1016 - root_mean_squared_error: 32.6665 - val_loss: 1205.3206 - val_root_mean_squared_error: 34.7177 - lr: 1.0000e-04
# Epoch 44/300
# 215/215 [==============================] - 7s 32ms/step - loss: 1064.4158 - root_mean_squared_error: 32.6254 - val_loss: 1201.7717 - val_root_mean_squared_error: 34.6666 - lr: 1.0000e-04
# Epoch 45/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1064.7241 - root_mean_squared_error: 32.6301 - val_loss: 1208.8199 - val_root_mean_squared_error: 34.7681 - lr: 1.0000e-04
# Epoch 46/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1063.4542 - root_mean_squared_error: 32.6106 - val_loss: 1205.5742 - val_root_mean_squared_error: 34.7214 - lr: 1.0000e-04
# Epoch 47/300
# 215/215 [==============================] - 5s 22ms/step - loss: 1063.6101 - root_mean_squared_error: 32.6130 - val_loss: 1205.5103 - val_root_mean_squared_error: 34.7205 - lr: 1.0000e-04
# Epoch 48/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1061.8876 - root_mean_squared_error: 32.5866 - val_loss: 1203.2733 - val_root_mean_squared_error: 34.6882 - lr: 1.0000e-04
# Epoch 49/300
# 215/215 [==============================] - 8s 37ms/step - loss: 1063.9747 - root_mean_squared_error: 32.6186 - val_loss: 1200.7051 - val_root_mean_squared_error: 34.6512 - lr: 1.0000e-04
# Epoch 50/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1058.3732 - root_mean_squared_error: 32.5326 - val_loss: 1207.7258 - val_root_mean_squared_error: 34.7523 - lr: 1.0000e-04
# Epoch 51/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1059.9427 - root_mean_squared_error: 32.5568 - val_loss: 1198.2573 - val_root_mean_squared_error: 34.6159 - lr: 1.0000e-04
# Epoch 52/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1059.2213 - root_mean_squared_error: 32.5457 - val_loss: 1200.3976 - val_root_mean_squared_error: 34.6468 - lr: 1.0000e-04
# Epoch 53/300
# 215/215 [==============================] - 6s 26ms/step - loss: 1056.3877 - root_mean_squared_error: 32.5021 - val_loss: 1203.7527 - val_root_mean_squared_error: 34.6951 - lr: 1.0000e-04
# Epoch 54/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1056.9352 - root_mean_squared_error: 32.5105 - val_loss: 1201.1771 - val_root_mean_squared_error: 34.6580 - lr: 1.0000e-04
# Epoch 55/300
# 215/215 [==============================] - 8s 38ms/step - loss: 1056.2924 - root_mean_squared_error: 32.5007 - val_loss: 1198.1056 - val_root_mean_squared_error: 34.6137 - lr: 1.0000e-04
# Epoch 56/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1057.5601 - root_mean_squared_error: 32.5201 - val_loss: 1202.8724 - val_root_mean_squared_error: 34.6824 - lr: 1.0000e-04
# Epoch 57/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1060.9301 - root_mean_squared_error: 32.5719 - val_loss: 1207.3154 - val_root_mean_squared_error: 34.7464 - lr: 1.0000e-04
# Epoch 58/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1056.1367 - root_mean_squared_error: 32.4983 - val_loss: 1205.6497 - val_root_mean_squared_error: 34.7225 - lr: 1.0000e-04
# Epoch 59/300
# 215/215 [==============================] - 6s 25ms/step - loss: 1055.2534 - root_mean_squared_error: 32.4847 - val_loss: 1199.8527 - val_root_mean_squared_error: 34.6389 - lr: 1.0000e-04
# Epoch 60/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1052.6322 - root_mean_squared_error: 32.4443 - val_loss: 1200.1497 - val_root_mean_squared_error: 34.6432 - lr: 1.0000e-04
# Epoch 61/300
# 215/215 [==============================] - 6s 26ms/step - loss: 1056.8503 - root_mean_squared_error: 32.5092 - val_loss: 1203.3400 - val_root_mean_squared_error: 34.6892 - lr: 1.0000e-04
# Epoch 62/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1053.2552 - root_mean_squared_error: 32.4539 - val_loss: 1196.5662 - val_root_mean_squared_error: 34.5914 - lr: 1.0000e-04
# Epoch 63/300
# 215/215 [==============================] - 7s 32ms/step - loss: 1054.8857 - root_mean_squared_error: 32.4790 - val_loss: 1195.5571 - val_root_mean_squared_error: 34.5768 - lr: 1.0000e-04
# Epoch 64/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1055.3408 - root_mean_squared_error: 32.4860 - val_loss: 1204.1997 - val_root_mean_squared_error: 34.7016 - lr: 1.0000e-04
# Epoch 65/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1054.6034 - root_mean_squared_error: 32.4747 - val_loss: 1196.3243 - val_root_mean_squared_error: 34.5879 - lr: 1.0000e-04
# Epoch 66/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1052.2739 - root_mean_squared_error: 32.4388 - val_loss: 1199.6638 - val_root_mean_squared_error: 34.6362 - lr: 1.0000e-04
# Epoch 67/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1049.8438 - root_mean_squared_error: 32.4013 - val_loss: 1204.1688 - val_root_mean_squared_error: 34.7011 - lr: 1.0000e-04
# Epoch 68/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1051.9556 - root_mean_squared_error: 32.4339 - val_loss: 1200.7467 - val_root_mean_squared_error: 34.6518 - lr: 1.0000e-04
# Epoch 69/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1051.0109 - root_mean_squared_error: 32.4193 - val_loss: 1200.1050 - val_root_mean_squared_error: 34.6425 - lr: 1.0000e-04
# Epoch 70/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1050.2041 - root_mean_squared_error: 32.4069 - val_loss: 1197.6415 - val_root_mean_squared_error: 34.6070 - lr: 1.0000e-04
# Epoch 71/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1048.7361 - root_mean_squared_error: 32.3842 - val_loss: 1200.4546 - val_root_mean_squared_error: 34.6476 - lr: 1.0000e-04
# Epoch 72/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1049.5802 - root_mean_squared_error: 32.3972 - val_loss: 1204.4865 - val_root_mean_squared_error: 34.7057 - lr: 1.0000e-04
# Epoch 73/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1049.2039 - root_mean_squared_error: 32.3914 - val_loss: 1197.4797 - val_root_mean_squared_error: 34.6046 - lr: 1.0000e-04
# Epoch 74/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1052.5189 - root_mean_squared_error: 32.4425 - val_loss: 1195.9784 - val_root_mean_squared_error: 34.5829 - lr: 1.0000e-05
# Epoch 75/300
# 215/215 [==============================] - 8s 37ms/step - loss: 1049.5221 - root_mean_squared_error: 32.3963 - val_loss: 1195.4923 - val_root_mean_squared_error: 34.5759 - lr: 1.0000e-05
# Epoch 76/300
# 215/215 [==============================] - 7s 32ms/step - loss: 1047.0557 - root_mean_squared_error: 32.3582 - val_loss: 1194.9579 - val_root_mean_squared_error: 34.5682 - lr: 1.0000e-05
# Epoch 77/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1045.6554 - root_mean_squared_error: 32.3366 - val_loss: 1196.2499 - val_root_mean_squared_error: 34.5868 - lr: 1.0000e-05
# Epoch 78/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1051.2303 - root_mean_squared_error: 32.4227 - val_loss: 1197.3865 - val_root_mean_squared_error: 34.6033 - lr: 1.0000e-05
# Epoch 79/300
# 215/215 [==============================] - 7s 32ms/step - loss: 1048.9811 - root_mean_squared_error: 32.3880 - val_loss: 1195.5339 - val_root_mean_squared_error: 34.5765 - lr: 1.0000e-05
# Epoch 80/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1046.9912 - root_mean_squared_error: 32.3572 - val_loss: 1195.4471 - val_root_mean_squared_error: 34.5752 - lr: 1.0000e-05
# Epoch 81/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1047.4894 - root_mean_squared_error: 32.3649 - val_loss: 1195.0825 - val_root_mean_squared_error: 34.5700 - lr: 1.0000e-05
# Epoch 82/300
# 215/215 [==============================] - 7s 32ms/step - loss: 1046.2960 - root_mean_squared_error: 32.3465 - val_loss: 1194.3013 - val_root_mean_squared_error: 34.5587 - lr: 1.0000e-05
# Epoch 83/300
# 215/215 [==============================] - 4s 21ms/step - loss: 1045.9554 - root_mean_squared_error: 32.3412 - val_loss: 1196.7585 - val_root_mean_squared_error: 34.5942 - lr: 1.0000e-05
# Epoch 84/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1046.8662 - root_mean_squared_error: 32.3553 - val_loss: 1195.1350 - val_root_mean_squared_error: 34.5707 - lr: 1.0000e-05
# Epoch 85/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1048.8845 - root_mean_squared_error: 32.3865 - val_loss: 1195.6776 - val_root_mean_squared_error: 34.5786 - lr: 1.0000e-05
# Epoch 86/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1045.0474 - root_mean_squared_error: 32.3272 - val_loss: 1195.7098 - val_root_mean_squared_error: 34.5790 - lr: 1.0000e-05
# Epoch 87/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1045.7008 - root_mean_squared_error: 32.3373 - val_loss: 1196.4342 - val_root_mean_squared_error: 34.5895 - lr: 1.0000e-05
# Epoch 88/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1046.5741 - root_mean_squared_error: 32.3508 - val_loss: 1194.6295 - val_root_mean_squared_error: 34.5634 - lr: 1.0000e-05
# Epoch 89/300
# 215/215 [==============================] - 5s 24ms/step - loss: 1047.9827 - root_mean_squared_error: 32.3726 - val_loss: 1195.7533 - val_root_mean_squared_error: 34.5797 - lr: 1.0000e-05
# Epoch 90/300
# 215/215 [==============================] - 7s 33ms/step - loss: 1044.9614 - root_mean_squared_error: 32.3259 - val_loss: 1194.1658 - val_root_mean_squared_error: 34.5567 - lr: 1.0000e-05
# Epoch 91/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1046.4775 - root_mean_squared_error: 32.3493 - val_loss: 1195.0322 - val_root_mean_squared_error: 34.5692 - lr: 1.0000e-05
# Epoch 92/300
# 215/215 [==============================] - 4s 21ms/step - loss: 1046.9763 - root_mean_squared_error: 32.3570 - val_loss: 1195.3645 - val_root_mean_squared_error: 34.5740 - lr: 1.0000e-05
# Epoch 93/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1045.7704 - root_mean_squared_error: 32.3384 - val_loss: 1196.0424 - val_root_mean_squared_error: 34.5838 - lr: 1.0000e-05
# Epoch 94/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1043.7433 - root_mean_squared_error: 32.3070 - val_loss: 1195.8837 - val_root_mean_squared_error: 34.5816 - lr: 1.0000e-05
# Epoch 95/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1042.7371 - root_mean_squared_error: 32.2914 - val_loss: 1196.6670 - val_root_mean_squared_error: 34.5929 - lr: 1.0000e-05
# Epoch 96/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1045.5410 - root_mean_squared_error: 32.3348 - val_loss: 1194.7166 - val_root_mean_squared_error: 34.5647 - lr: 1.0000e-05
# Epoch 97/300
# 215/215 [==============================] - 5s 24ms/step - loss: 1044.7955 - root_mean_squared_error: 32.3233 - val_loss: 1196.4891 - val_root_mean_squared_error: 34.5903 - lr: 1.0000e-05
# Epoch 98/300
# 215/215 [==============================] - 5s 25ms/step - loss: 1045.5404 - root_mean_squared_error: 32.3348 - val_loss: 1195.5298 - val_root_mean_squared_error: 34.5764 - lr: 1.0000e-05
# Epoch 99/300
# 215/215 [==============================] - 9s 40ms/step - loss: 1043.8243 - root_mean_squared_error: 32.3083 - val_loss: 1193.9935 - val_root_mean_squared_error: 34.5542 - lr: 1.0000e-05
# Epoch 100/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1043.9667 - root_mean_squared_error: 32.3105 - val_loss: 1195.3920 - val_root_mean_squared_error: 34.5744 - lr: 1.0000e-05
# Epoch 101/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1046.5410 - root_mean_squared_error: 32.3503 - val_loss: 1194.7585 - val_root_mean_squared_error: 34.5653 - lr: 1.0000e-05
# Epoch 102/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1044.1580 - root_mean_squared_error: 32.3134 - val_loss: 1194.3146 - val_root_mean_squared_error: 34.5589 - lr: 1.0000e-05
# Epoch 103/300
# 215/215 [==============================] - 5s 25ms/step - loss: 1045.0225 - root_mean_squared_error: 32.3268 - val_loss: 1194.5311 - val_root_mean_squared_error: 34.5620 - lr: 1.0000e-05
# Epoch 104/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1044.6465 - root_mean_squared_error: 32.3210 - val_loss: 1195.5372 - val_root_mean_squared_error: 34.5765 - lr: 1.0000e-05
# Epoch 105/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1046.6757 - root_mean_squared_error: 32.3524 - val_loss: 1195.6571 - val_root_mean_squared_error: 34.5783 - lr: 1.0000e-05
# Epoch 106/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1046.6761 - root_mean_squared_error: 32.3524 - val_loss: 1195.9973 - val_root_mean_squared_error: 34.5832 - lr: 1.0000e-05
# Epoch 107/300
# 215/215 [==============================] - 5s 21ms/step - loss: 1044.8362 - root_mean_squared_error: 32.3239 - val_loss: 1195.8566 - val_root_mean_squared_error: 34.5812 - lr: 1.0000e-05
# Epoch 108/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1048.9335 - root_mean_squared_error: 32.3872 - val_loss: 1195.3613 - val_root_mean_squared_error: 34.5740 - lr: 1.0000e-05
# Epoch 109/300
# 215/215 [==============================] - 7s 35ms/step - loss: 1043.9194 - root_mean_squared_error: 32.3097 - val_loss: 1194.8761 - val_root_mean_squared_error: 34.5670 - lr: 1.0000e-05
# Epoch 110/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1043.5226 - root_mean_squared_error: 32.3036 - val_loss: 1195.2439 - val_root_mean_squared_error: 34.5723 - lr: 1.0000e-06
# Epoch 111/300
# 215/215 [==============================] - 6s 26ms/step - loss: 1046.3485 - root_mean_squared_error: 32.3473 - val_loss: 1195.1534 - val_root_mean_squared_error: 34.5710 - lr: 1.0000e-06
# Epoch 112/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1043.2941 - root_mean_squared_error: 32.3001 - val_loss: 1195.3213 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-06
# Epoch 113/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1045.5979 - root_mean_squared_error: 32.3357 - val_loss: 1195.2211 - val_root_mean_squared_error: 34.5720 - lr: 1.0000e-06
# Epoch 114/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1043.4459 - root_mean_squared_error: 32.3024 - val_loss: 1195.4443 - val_root_mean_squared_error: 34.5752 - lr: 1.0000e-06
# Epoch 115/300
# 215/215 [==============================] - 6s 28ms/step - loss: 1042.8811 - root_mean_squared_error: 32.2937 - val_loss: 1195.7172 - val_root_mean_squared_error: 34.5791 - lr: 1.0000e-06
# Epoch 116/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1045.8954 - root_mean_squared_error: 32.3403 - val_loss: 1195.3866 - val_root_mean_squared_error: 34.5744 - lr: 1.0000e-06
# Epoch 117/300
# 215/215 [==============================] - 5s 23ms/step - loss: 1044.8188 - root_mean_squared_error: 32.3237 - val_loss: 1195.1415 - val_root_mean_squared_error: 34.5708 - lr: 1.0000e-06
# Epoch 118/300
# 215/215 [==============================] - 5s 24ms/step - loss: 1040.9026 - root_mean_squared_error: 32.2630 - val_loss: 1195.2983 - val_root_mean_squared_error: 34.5731 - lr: 1.0000e-06
# Epoch 119/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1045.1592 - root_mean_squared_error: 32.3289 - val_loss: 1195.4115 - val_root_mean_squared_error: 34.5747 - lr: 1.0000e-06
# Epoch 120/300
# 215/215 [==============================] - 6s 26ms/step - loss: 1044.7885 - root_mean_squared_error: 32.3232 - val_loss: 1195.3759 - val_root_mean_squared_error: 34.5742 - lr: 1.0000e-07
# Epoch 121/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1042.0374 - root_mean_squared_error: 32.2806 - val_loss: 1195.3837 - val_root_mean_squared_error: 34.5743 - lr: 1.0000e-07
# Epoch 122/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1042.5765 - root_mean_squared_error: 32.2890 - val_loss: 1195.4092 - val_root_mean_squared_error: 34.5747 - lr: 1.0000e-07
# Epoch 123/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1046.1030 - root_mean_squared_error: 32.3435 - val_loss: 1195.3722 - val_root_mean_squared_error: 34.5742 - lr: 1.0000e-07
# Epoch 124/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1045.2306 - root_mean_squared_error: 32.3300 - val_loss: 1195.3854 - val_root_mean_squared_error: 34.5743 - lr: 1.0000e-07
# Epoch 125/300
# 215/215 [==============================] - 5s 24ms/step - loss: 1045.9916 - root_mean_squared_error: 32.3418 - val_loss: 1195.3647 - val_root_mean_squared_error: 34.5740 - lr: 1.0000e-07
# Epoch 126/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1043.0833 - root_mean_squared_error: 32.2968 - val_loss: 1195.3724 - val_root_mean_squared_error: 34.5742 - lr: 1.0000e-07
# Epoch 127/300
# 215/215 [==============================] - 5s 26ms/step - loss: 1044.8250 - root_mean_squared_error: 32.3237 - val_loss: 1195.3658 - val_root_mean_squared_error: 34.5741 - lr: 1.0000e-07
# Epoch 128/300
# 215/215 [==============================] - 6s 29ms/step - loss: 1044.7134 - root_mean_squared_error: 32.3220 - val_loss: 1195.3448 - val_root_mean_squared_error: 34.5738 - lr: 1.0000e-07
# Epoch 129/300
# 215/215 [==============================] - 5s 22ms/step - loss: 1043.8129 - root_mean_squared_error: 32.3081 - val_loss: 1195.3198 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-07
# Epoch 130/300
# 215/215 [==============================] - 5s 22ms/step - loss: 1045.0569 - root_mean_squared_error: 32.3273 - val_loss: 1195.3171 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-08
# Epoch 131/300
# 215/215 [==============================] - 4s 20ms/step - loss: 1042.8114 - root_mean_squared_error: 32.2926 - val_loss: 1195.3160 - val_root_mean_squared_error: 34.5733 - lr: 1.0000e-08
# Epoch 132/300
# 215/215 [==============================] - 6s 27ms/step - loss: 1045.1627 - root_mean_squared_error: 32.3290 - val_loss: 1195.3170 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-08
# Epoch 133/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1042.0575 - root_mean_squared_error: 32.2809 - val_loss: 1195.3208 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-08
# Epoch 134/300
# 215/215 [==============================] - 4s 19ms/step - loss: 1044.7839 - root_mean_squared_error: 32.3231 - val_loss: 1195.3203 - val_root_mean_squared_error: 34.5734 - lr: 1.0000e-08
# Evaluating on patient_id: 559
# all rolling: 2420
# 2208 size before reduction
# 2208 size after reduction
# 75 windows with too many nans
# 120 windows with empty labels
# all rolling: 2876
# 2335 size before reduction
# 2335 size after reduction
# 175 windows with too many nans
# 349 windows with empty labels
# Evaluating on patient_id: 563
# all rolling: 2627
# 2431 size before reduction
# 2431 size after reduction
# 77 windows with too many nans
# 102 windows with empty labels
# all rolling: 2814
# 2526 size before reduction
# 2526 size after reduction
# 37 windows with too many nans
# 234 windows with empty labels
# Evaluating on patient_id: 570
# all rolling: 2362
# 2133 size before reduction
# 2133 size after reduction
# 79 windows with too many nans
# 133 windows with empty labels
# all rolling: 2880
# 2618 size before reduction
# 2618 size after reduction
# 123 windows with too many nans
# 122 windows with empty labels
# Evaluating on patient_id: 575
# all rolling: 2621
# 2355 size before reduction
# 2355 size after reduction
# 94 windows with too many nans
# 155 windows with empty labels
# all rolling: 2745
# 2466 size before reduction
# 2466 size after reduction
# 118 windows with too many nans
# 144 windows with empty labels
# Evaluating on patient_id: 588
# all rolling: 2650
# 2600 size before reduction
# 2600 size after reduction
# 18 windows with too many nans
# 15 windows with empty labels
# all rolling: 2880
# 2741 size before reduction
# 2741 size after reduction
# 38 windows with too many nans
# 84 windows with empty labels
# Evaluating on patient_id: 591
# all rolling: 2592
# 2493 size before reduction
# 2493 size after reduction
# 31 windows with too many nans
# 51 windows with empty labels
# all rolling: 2847
# 2697 size before reduction
# 2697 size after reduction
# 50 windows with too many nans
# 83 windows with empty labels

# %%
df_results_test = pd.DataFrame(test_errs, columns=['Model iteration', 'Patient ID', 'RMSE'])
df_results_test['Model'] = df_results_test['Model iteration'].str.replace(r'_\d+$', '', regex=True)

df_results_test.groupby(['Model iteration'])['RMSE'].agg(['mean'])
# Out:
#                                    mean
# Model iteration
# lmu_2018_ph60min_full_wins_0  30.181339
